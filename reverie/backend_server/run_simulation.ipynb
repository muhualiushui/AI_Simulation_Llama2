# %%
for i in range(2,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand7\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/11_15/output_11_15_$i"
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 405, in start_server
#     with open(curr_move_file, "w") as outfile:
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../../environment/frontend_server/storage/rand7/movement/0.json'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 639, in _determine_action
#     act_obj_desp = generate_act_obj_desc(act_game_object, act_desp, persona)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 269, in generate_act_obj_desc
#     return run_gpt_prompt_act_obj_desc(act_game_object, act_desp, persona)[0]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 405, in start_server
#     with open(curr_move_file, "w") as outfile:
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../../environment/frontend_server/storage/rand7/movement/0.json'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 258, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 430, in __func_clean_up
#     last_task = curr_min_slot[-1]
#                 ~~~~~~~~~~~~~^^^^
# IndexError: list index out of range
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 107, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'Isabella Rodriguez should go to her bedroom for sleeping.'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 633, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 109, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'isabella rodriguez should go to her bedroom for sleeping.'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 639, in _determine_action
#     act_obj_desp = generate_act_obj_desc(act_game_object, act_desp, persona)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 269, in generate_act_obj_desc
#     return run_gpt_prompt_act_obj_desc(act_game_object, act_desp, persona)[0]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 107, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'bedroom'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 633, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 109, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'bedroom'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 258, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 430, in __func_clean_up
#     last_task = curr_min_slot[-1]
#                 ~~~~~~~~~~~~~^^^^
# IndexError: list index out of range

# %%
for i in range(2,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand2\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_$i"
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 257, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 407, in __func_clean_up
#     duration = int(k[1].split(",")[0].strip())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'x'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'

# %%
! echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# GNS FUNCTION: <generate_wake_up_hour>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez typically wakes up at 6am every day.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez typically wakes up at 6am every day.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez usually wakes up at 6am.
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Isabella']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Isabella's wake up hour:
#
# ~~~ prompt    ----------------------------------------------------
# 8
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez plans on starting her day by completing her morning routine at 8:00 am. She will then open Hobbs Cafe and work at the counter from 8:00 am until 8:00 pm, when she will close the cafe for the day.
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Monday February 13', 'Isabella', '8:00 am']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Today is Monday February 13. Here is Isabella's plan today in broad-strokes (with the time of the day. e.g., have a lunch at 12:00 pm, watch TV from 7 to 8 pm): 1) wake up and complete the morning routine at 8:00 am, 2)
#
# ~~~ prompt    ----------------------------------------------------
# ['wake up and complete the morning routine at 8:00 am']
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# preparing breakfast for her family.
# [(ID:1g6FK9) Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [(ID:4t5QMh) Monday February 13 -- 10:00 AM] Activity: Isabella goes to the grocery store to stock up on supplies for the cafe.
# [(ID:2c7qvT) Monday February 13 -- 11:00 AM] Activity: Isabella goes to the cafe and begins prepping for the day.
# [(ID:6mXr9e) Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [(ID:3jQZWt) Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [(ID:3dV97c) Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:3jLXvK) Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [(ID:4u7Jdg) Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:2jKnjN) Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [(ID:5zFJ3f) Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [(ID:5gLw6a) Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:NqU49w) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:NmhcbB) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:fxNh3p) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:5Zlws5) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:VKsOj3) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:ne1Rms) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:F1MVTg) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:7PrUiX) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am", '', '[(ID:FLTu1U) Monday February 13 -- 08:00 AM] Activity: Isabella is']
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:NqU49w) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:NmhcbB) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:fxNh3p) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:5Zlws5) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:VKsOj3) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:ne1Rms) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:F1MVTg) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:7PrUiX) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:FLTu1U) Monday February 13 -- 08:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# preparing breakfast for her family.
# [(ID:1g6FK9) Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [(ID:4t5QMh) Monday February 13 -- 10:00 AM] Activity: Isabella goes to the grocery store to stock up on supplies for the cafe.
# [(ID:2c7qvT) Monday February 13 -- 11:00 AM] Activity: Isabella goes to the cafe and begins prepping for the day.
# [(ID:6mXr9e) Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [(ID:3jQZWt) Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [(ID:3dV97c) Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:3jLXvK) Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [(ID:4u7Jdg) Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:2jKnjN) Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [(ID:5zFJ3f) Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [(ID:5gLw6a) Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Here is the hourly breakdown of Isabella's schedule for Monday, February 13th:
#
# [Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 08:00 AM] Activity: Isabella prepares breakfast for her family.
# [Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [Monday February 13 -- 10:00 AM] Activity: Isabella goes grocery shopping.
# [Monday February 13 -- 11:00 AM] Activity: Isabella arrives at Hobbs Cafe and begins preparing for the day.
# [Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:mLCxT9) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:4RsnQo) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:bCLCMR) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:JrQfUh) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:nqknbr) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:uF4bh7) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:BoqwLj) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:XAQ42d) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:T80OJ6) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for her family.\n[(ID:1g6FK9) Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.\n[(ID:4t5QMh) Monday February 13 -- 10:00 AM] Activity: Isabella goes to the grocery store to stock up on supplies for the cafe.\n[(ID:2c7qvT) Monday February 13 -- 11:00 AM] Activity: Isabella goes to the cafe and begins prepping for the day.\n[(ID:6mXr9e) Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.\n[(ID:3jQZWt) Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.\n[(ID:3dV97c) Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.\n[(ID:3jLXvK) Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.\n[(ID:4u7Jdg) Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.\n[(ID:2jKnjN) Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up t ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:mLCxT9) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:4RsnQo) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:bCLCMR) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:JrQfUh) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:nqknbr) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:uF4bh7) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:BoqwLj) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:XAQ42d) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:T80OJ6) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for her family.
# [(ID:1g6FK9) Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [(ID:4t5QMh) Monday February 13 -- 10:00 AM] Activity: Isabella goes to the grocery store to stock up on supplies for the cafe.
# [(ID:2c7qvT) Monday February 13 -- 11:00 AM] Activity: Isabella goes to the cafe and begins prepping for the day.
# [(ID:6mXr9e) Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [(ID:3jQZWt) Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [(ID:3dV97c) Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:3jLXvK) Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [(ID:4u7Jdg) Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:2jKnjN) Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [(ID:5zFJ3f) Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [(ID:5gLw6a) Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:FcqKHm) Monday February 13 -- 09:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# Here is the hourly breakdown of Isabella's schedule for Monday, February 13th:
#
# [Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 08:00 AM] Activity: Isabella prepares breakfast for her family.
# [Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [Monday February 13 -- 10:00 AM] Activity: Isabella goes grocery shopping.
# [Monday February 13 -- 11:00 AM] Activity: Isabella arrives at Hobbs Cafe and begins preparing for the day.
# [Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# going grocery shopping.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:jOtpR0) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:AkSCg7) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:eUgsWQ) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:PDgAqh) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:aCUV83) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:g53jci) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:gFSGWh) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:tcmVoI) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:06tkaF) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for her family.\n[(ID:1g6FK9) Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.\n[(ID:4t5QMh) Monday February 13 -- 10:00 AM] Activity: Isabella goes to the grocery store to stock up on supplies for the cafe.\n[(ID:2c7qvT) Monday February 13 -- 11:00 AM] Activity: Isabella goes to the cafe and begins prepping for the day.\n[(ID:6mXr9e) Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.\n[(ID:3jQZWt) Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.\n[(ID:3dV97c) Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.\n[(ID:3jLXvK) Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.\n[(ID:4u7Jdg) Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.\n[(ID:2jKnjN) Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up t ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:jOtpR0) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:AkSCg7) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:eUgsWQ) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:PDgAqh) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:aCUV83) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:g53jci) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:gFSGWh) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:tcmVoI) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:06tkaF) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for her family.
# [(ID:1g6FK9) Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [(ID:4t5QMh) Monday February 13 -- 10:00 AM] Activity: Isabella goes to the grocery store to stock up on supplies for the cafe.
# [(ID:2c7qvT) Monday February 13 -- 11:00 AM] Activity: Isabella goes to the cafe and begins prepping for the day.
# [(ID:6mXr9e) Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [(ID:3jQZWt) Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [(ID:3dV97c) Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:3jLXvK) Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [(ID:4u7Jdg) Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [(ID:2jKnjN) Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [(ID:5zFJ3f) Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [(ID:5gLw6a) Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration
# [(ID:9bEoD8) Monday February 13 -- 09:00 AM] Activity: Isabella is Here is the hourly breakdown of Isabella's schedule for Monday, February 13th:
#
# [Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [Monday February 13 -- 08:00 AM] Activity: Isabella prepares breakfast for her family.
# [Monday February 13 -- 09:00 AM] Activity: Isabella takes her children to school and then goes back home.
# [Monday February 13 -- 10:00 AM] Activity: Isabella goes grocery shopping.
# [Monday February 13 -- 11:00 AM] Activity: Isabella arrives at Hobbs Cafe and begins preparing for the day.
# [Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
# [Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
# [Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
# [Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
# [Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
# [Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
# [Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:wHcpKK) Monday February 13 -- 10:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# going grocery shopping
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez has a busy schedule on Monday, February 13th. Her daily plan requires her to open Hobbs Cafe at 8am and work until 8pm. Here's an hourly breakdown of Isabella's activities for the day:
#
# [Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
#
# [Monday February 13 -- 07:00 AM] Activity: Isabella prepares breakfast for her family.
#
# [Monday February 13 -- 08:00 AM] Activity: Isabella takes her children to school and then goes back home.
#
# [Monday February 13 -- 09:00 AM] Activity: Isabella is not specified at this time.
#
# [Monday February 13 -- 10:00 AM] Activity: Isabella goes grocery shopping.
#
# [Monday February 13 -- 11:00 AM] Activity: Isabella arrives at Hobbs Cafe and begins preparing for the day.
#
# [Monday February 13 -- 12:00 PM] Activity: Hobbs Cafe opens at 12pm, and Isabella greets customers and starts serving their orders.
#
# [Monday February 13 -- 01:00 PM] Activity: Isabella takes a break to eat lunch with her employees.
#
# [Monday February 13 -- 02:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
#
# [Monday February 13 -- 03:00 PM] Activity: Isabella finishes preparing for the Valentine's Day party and begins setting up the cafe.
#
# [Monday February 13 -- 04:00 PM] Activity: Hobbs Cafe is busy, and Isabella keeps working hard to make sure everyone's needs are met.
#
# [Monday February 13 -- 05:00 PM] Activity: Isabella finishes setting up the cafe for the Valentine's Day party and begins promoting it to customers.
#
# [Monday February 13 -- 06:00 PM] Activity: Hobbs Cafe opens at 6pm, and Isabella greets customers and starts serving their orders.
#
# [Monday February 13 -- 07:00 PM] Activity: The Valentine's Day party begins at 7pm, and Isabella welcomes her customers to the celebration.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ...
# ['Based on the given information, the hourly breakdown of Klaus\'s schedule for Monday, February 13th could be as follows:\n\n* From 7:00am to 9:00am: Wake up and complete morning routine.\n* From 9:00am to 12:00pm: Go to Oak Hill College library for early morning research and study.\n* From 12:00pm to 1:00pm: Eat lunch at Hobbs Cafe before returning to Oak Hill College library for research and study.\n* From 1:00pm to 3:00pm: Continue work on the finalizing of his research paper.\n* From 3:00pm to 5:00pm: Take a break for lunch at noon.\n* From 5:00pm to 7:00pm: Take a break for dinner at Hobbs Cafe.\n* From 7:00pm to 9:00pm: Return to Oak Hill College library for research and study after dinner.\n* From 9:00pm to 10:00pm: Finish the final touches of his research paper before bedtime.\nNote that this hourly breakdown is based on the information provided in the prompt, but it may not necessarily reflect the actual activities that Klaus does throughout the day. Additionally, some activities such as "work on the finalizing of the research paper" and "taking a break for dinner at Hobbs Cafe" are not explicitly stated in the prompt, so they have been added based on logical deductions from the given information.\nI hope this helps! Let me know if you have any further questions or concerns', 60]
# ['Klaus is a student who needs to complete his research paper before the deadline. He is expected to work on it for several hours but he cannot make any progress and he feels overwhelmed. Please assist him in finding information related to his research topic and provide suggestions on how he can manage his time more effectively', 60]
# 0
# 17
# Klaus Mueller
# ------
# GNS FUNCTION: <generate_action_sector>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Dorm for Oak Hill College}
# DEBUG The Willows Market and Pharmacy ------ Dorm for Oak Hill College
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Klaus Mueller
#
# ~~~ gpt_param ----------------------------------------------------
# ['Klaus Mueller', 'Dorm for Oak Hill College', "garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen, Maria Lopez's room", 'Klaus Mueller', 'Dorm for Oak Hill College', "garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen, Maria Lopez's room", '\nKlaus Mueller goes to the library at Oak Hill College early in the morning, spends his days writing, and eats at Hobbs Cafe.', 'Oak Hill College, Dorm for Oak Hill College, The Willows Market and Pharmacy, Harvey Oak Supply Store, Johnson Park, The Rose and Crown Pub, Hobbs Cafe', 'Klaus Mueller', 'sleeping', 'sleeping', 'Klaus Mueller']
#
# ~~~ prompt_input    ----------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Klaus Mueller lives in {Dorm for Oak Hill College} that has garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen, Maria Lopez's room.
# Klaus Mueller is currently in {Dorm for Oak Hill College} that has garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen, Maria Lopez's room.
# Klaus Mueller goes to the library at Oak Hill College early in the morning, spends his days writing, and eats at Hobbs Cafe.
# Area options: {Oak Hill College, Dorm for Oak Hill College, The Willows Market and Pharmacy, Harvey Oak Supply Store, Johnson Park, The Rose and Crown Pub, Hobbs Cafe}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Klaus Mueller is sleeping. For sleeping, Klaus Mueller should go to the following area: {
#
# ~~~ prompt    ----------------------------------------------------
# Dorm for Oak Hill College
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_arena>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Klaus Mueller's room}
# === persona/prompt_template/v1/action_location_object_vMar12.txt
# ~~~ persona    ---------------------------------------------------
# Klaus Mueller
#
# ~~~ gpt_param ----------------------------------------------------
# ['Klaus Mueller', 'Dorm for Oak Hill College', "garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen", 'Klaus Mueller', 'sleeping', 'sleeping', 'Klaus Mueller', 'Dorm for Oak Hill College', "garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen"]
#
# ~~~ prompt_input    ----------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# *** Must pick answer from the list: {kitchen,  bedroom, bathroom}
# For cooking, Jane Anderson should go to which area in Jane Anderson's house:
# Answer: {kitchen}
# ---
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# *** Must pick answer from the list: {cafe}
# For getting coffee, Tom Watson should go to which area in Hobbs Cafe:
# Answer: {cafe}
# ---
#
#
# Now your turn:
# Klaus Mueller is going to Dorm for Oak Hill College that has the following areas: {garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen}
# * Stay in the current area if the activity can be done there.
# * Never go into other people's rooms unless necessary.
# *** Must pick answer from the list: {garden, Klaus Mueller's room, woman's bathroom, common room, man's bathroom, kitchen}
# Klaus Mueller is sleeping. For sleeping, Klaus Mueller should go to which area in Dorm for Oak Hill College:
# Answer: {
#
# ~~~ prompt    ----------------------------------------------------
# Klaus Mueller's room
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# Klaus Mueller's room
# Klaus Mueller's room
# Identified?????????????????????????????????????/
# Klaus Mueller's room
# Klaus Mueller's room
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# bed
# Identified?????????????????????????????????????/
# Klaus Mueller's room
# Klaus Mueller's room
# === persona/prompt_template/v1/action_object_v2.txt
# ~~~ persona    ---------------------------------------------------
# Klaus Mueller
#
# ~~~ gpt_param ----------------------------------------------------
# ['sleeping', 'bed, game console, closet, desk']
#
# ~~~ prompt_input    ----------------------------------------------
# Current activity: sleep in bed
# Objects available: {bed, easel, closet, painting}
# Pick ONE most relevant object from the objects available: bed
# ---
# Current activity: painting
# Objects available: {easel, closet, sink, microwave}
# Pick ONE most relevant object from the objects available: easel
# ---
# Current activity: cooking
# Objects available: {stove, sink, fridge, counter}
# Pick ONE most relevant object from the objects available: stove
# ---
# Current activity: watch TV
# Objects available: {couch, TV, remote, coffee table}
# Pick ONE most relevant object from the objects available: TV
# ---
# Current activity: study
# Objects available: {desk, computer, chair, bookshelf}
# Pick ONE most relevant object from the objects available: desk
# ---
# Current activity: talk on the phone
# Objects available: {phone, charger, bed, nightstand}
# Pick ONE most relevant object from the objects available: phone
# ---
# Current activity: sleeping
# Objects available: {bed, game console, closet, desk}
# Pick ONE most relevant object from the objects available:
#
# ~~~ prompt    ----------------------------------------------------
# bed
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: sleeping
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 🛏️
# GNS FUNCTION: <generate_action_event_triple>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# is, sleep)
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Klaus Mueller
#
# ~~~ gpt_param ----------------------------------------------------
# ['Klaus Mueller', 'sleeping', 'Klaus Mueller']
#
# ~~~ prompt_input    ----------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: Klaus Mueller is sleeping.
# Output: (Klaus Mueller,
#
# ~~~ prompt    ----------------------------------------------------
# ('Klaus Mueller', 'is', 'sleep')
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_act_obj_desc>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 6
# CHAT GPT PROMPT
# """
# Task: We want to understand the state of an object that is being used by someone.
#
# ---
# Example 1:
# Kelly is writing on the desk
# desk is: using by Kelly
#
# Example 2:
# Jason is fixing the TV
# Tv is: fixing by Jason
#
# Example 3:
# Jessica is spleeping on the bed
# bed is: using by Jessica
# ---
#
# Now, We want to know about bed's state.
# Klaus Mueller is sleeping with the bed.
# bed is:
# """
# Output the response to the prompt above in json. The output should ONLY contain the phrase that should go in <fill in>.
# Example output json:
# {"output": "being fixed"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# using
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: using
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 🔍👨‍💻
# GNS FUNCTION: <generate_act_obj_event_triple>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Input: Jill Smith is watching TV.
# Output: (Jill Smith, watch, TV)
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Input: Using a bed is comfortable.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Input: Using a bed is not a good idea.
# Output: (bed, is using, not good idea)
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# use)
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Using, sleep)
# ---
# Input: The cat is sitting on the table.
# Output: (cat, sit, table)
# ---
# Input: The book is being read by John.
# Output: (book, be read by, John)
# ---
# Input: Mary is playing music in her room.
# Output: (Mary, play, music)
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Klaus Mueller
#
# ~~~ gpt_param ----------------------------------------------------
# ['bed', 'using', 'bed']
#
# ~~~ prompt_input    ----------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: bed is using.
# Output: (bed,
#
# ~~~ prompt    ----------------------------------------------------
# ('bed', 'Using', 'sleep')
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Klaus Mueller persona.scratch.importance_trigger_curr:: 145
# 150
# aldhfoaf/????
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 405, in start_server
#     with open(curr_move_file, "w") as outfile:
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: '../../environment/frontend_server/storage/rand1/movement/0.json'
# Error.
# Enter option:
