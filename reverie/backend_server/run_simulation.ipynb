# %%
for i in range(1,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand7\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_rm_$i"
# Out:
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'

# %%
for i in range(2,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand2\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_$i"
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 257, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 407, in __func_clean_up
#     duration = int(k[1].split(",")[0].strip())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'x'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'

# %%
! echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# GNS FUNCTION: <generate_wake_up_hour>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The given information does not mention a specific wake-up hour for Isabella Rodriguez, but it says she usually wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez typically wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez usually wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez usually wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez usually wakes up at 6am every morning.
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Isabella']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Isabella's wake up hour:
#
# ~~~ prompt    ----------------------------------------------------
# 8
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez's plan for Monday February 13 could be as follows:
#
# 1. Wake up and complete the morning routine at 6:00 am.
# 2. Have breakfast at her home or outside at a cafe at around 7:30 am.
# 3. Drive to Hobbs Cafe and open the cafe at 8:00 am.
# 4. Work at the counter, making coffee, serving customers, and managing the cafe until 8:00 pm.
# 5. Close the cafe and go home for dinner or spend time with family.
# 6. Have dinner at around 7:30 pm.
# 7. Spend time with family, watching TV or reading a book.
# 8. Go to bed around 11:00 pm.
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Monday February 13', 'Isabella', '8:00 am']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Today is Monday February 13. Here is Isabella's plan today in broad-strokes (with the time of the day. e.g., have a lunch at 12:00 pm, watch TV from 7 to 8 pm): 1) wake up and complete the morning routine at 8:00 am, 2)
#
# ~~~ prompt    ----------------------------------------------------
# ['wake up and complete the morning routine at 8:00 am']
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.
# [(ID:qZ4gv7) Monday February 13 -- 08:30 AM] Activity: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.
# [(ID:z2W8hM) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.
# [(ID:6Kbz5w) Monday February 13 -- 10:00 AM] Activity: Isabella is working at the counter, taking orders, making drinks, and serving food to customers. She will also assist with cleaning tasks as needed.
# [(ID:2B9V6j) Monday February 13 -- 11:00 AM] Activity: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.
# [(ID:4KzqW7) Monday February 13 -- 12:00 PM] Activity: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:8XqDz5) Monday February 13 -- 1:00 PM] Activity: Isabella is preparing for dinner by making pastas, pizzas, and other dishes. She will also assist with setting the tables and cleaning up after customers as needed.
# [(ID:9J4B2k) Monday February 13 -- 2:00 PM] Activity: Isabella is serving dinner to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:3U6sLn) Monday February 13 -- 3:00 PM] Activity: Isabella is preparing for closing by cleaning up the kitchen, wiping down counters and tables, and ensuring that everything is in order before closing the cafe at 8:00 pm.
# [(ID:7JgK7x) Monday February 13 -- 4:00 PM] Activity: Isabella is finishing up cleaning tasks and preparing for the next day's opening. She will also take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
# [(ID:8JhDy8) Monday February 13 -- 5:00 PM] Activity: Isabella is preparing for her Valentine's Day party by setting up decorations, preparing food and drink options, and making sure that everything is ready for the event at 5:00 pm.
# [(ID:9JhXj1) Monday February 13 -- 6:00 PM] Activity: Isabella is hosting her Valentine's Day party and welcoming customers to Hobbs Cafe. She will greet guests, serve food and drinks, and ensure that everyone has a great time during the event.
# [(ID:8JgK7x) Monday February 13 -- 7:00 PM] Activity: Isabella is finishing up cleaning up after the Valentine's Day party and preparing for closing. She will make sure that everything is in order before closing the cafe at 8:00 pm.
# [(ID:3U6sLn) Monday February 13 -- 8:00 PM] Activity: Isabella is finishing up closing tasks and preparing for the next day's opening. She will take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
#
# [Isabella Rodriguez's schedule plan requirement: Isabella opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.]
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:aOfv6E) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:sdY6kz) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:qqA4Wv) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:cLmDns) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:xBSwd5) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:pdKazt) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:Tzx313) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:l2Ctn1) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am", '', '[(ID:3w45A0) Monday February 13 -- 08:00 AM] Activity: Isabella is']
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:aOfv6E) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:sdY6kz) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:qqA4Wv) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:cLmDns) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:xBSwd5) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:pdKazt) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:Tzx313) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:l2Ctn1) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:3w45A0) Monday February 13 -- 08:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.
# [(ID:qZ4gv7) Monday February 13 -- 08:30 AM] Activity: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.
# [(ID:z2W8hM) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.
# [(ID:6Kbz5w) Monday February 13 -- 10:00 AM] Activity: Isabella is working at the counter, taking orders, making drinks, and serving food to customers. She will also assist with cleaning tasks as needed.
# [(ID:2B9V6j) Monday February 13 -- 11:00 AM] Activity: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.
# [(ID:4KzqW7) Monday February 13 -- 12:00 PM] Activity: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:8XqDz5) Monday February 13 -- 1:00 PM] Activity: Isabella is preparing for dinner by making pastas, pizzas, and other dishes. She will also assist with setting the tables and cleaning up after customers as needed.
# [(ID:9J4B2k) Monday February 13 -- 2:00 PM] Activity: Isabella is serving dinner to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:3U6sLn) Monday February 13 -- 3:00 PM] Activity: Isabella is preparing for closing by cleaning up the kitchen, wiping down counters and tables, and ensuring that everything is in order before closing the cafe at 8:00 pm.
# [(ID:7JgK7x) Monday February 13 -- 4:00 PM] Activity: Isabella is finishing up cleaning tasks and preparing for the next day's opening. She will also take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
# [(ID:8JhDy8) Monday February 13 -- 5:00 PM] Activity: Isabella is preparing for her Valentine's Day party by setting up decorations, preparing food and drink options, and making sure that everything is ready for the event at 5:00 pm.
# [(ID:9JhXj1) Monday February 13 -- 6:00 PM] Activity: Isabella is hosting her Valentine's Day party and welcoming customers to Hobbs Cafe. She will greet guests, serve food and drinks, and ensure that everyone has a great time during the event.
# [(ID:8JgK7x) Monday February 13 -- 7:00 PM] Activity: Isabella is finishing up cleaning up after the Valentine's Day party and preparing for closing. She will make sure that everything is in order before closing the cafe at 8:00 pm.
# [(ID:3U6sLn) Monday February 13 -- 8:00 PM] Activity: Isabella is finishing up closing tasks and preparing for the next day's opening. She will take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
#
# [Isabella Rodriguez's schedule plan requirement: Isabella opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.]
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez's schedule breakdown for Monday, February 13th, 2023 from 9:00am to 7:00pm.
#
# 1) Wake up and complete morning routine (8:00-9:00am): [(ID:6PrMC8)]
# 2) Prepare breakfast for herself and employees (9:00-9:30am): [(ID:z2W8hM)]
# 3) Get ready for work, including makeup and hair styling (9:30-10:00am): [(ID:qZ4gv7)]
# 4) Open Hobbs Cafe and prepare for customers (10:00-11:00am): [(ID:z2W8hM)]
# 5) Work at the counter, taking orders, making drinks, and serving food to customers (11:00am-12:00pm): [(ID:6Kbz5w)]
# 6) Prepare lunch by making sandwiches, soups, and salads (12:00-1:00pm): [(ID:4KzqW7)]
# 7) Clean up after lunch and make sure the cafe looks its best (1:00-2:00pm): [(ID:8XqDz5)]
# 8) Prepare for dinner by making pastas, pizzas, and other dishes (2:00-3:00pm): [(ID:9J4B2k)]
# 9) Serve dinner to customers and assist with ordering and payment (3:00-4:00pm): [(ID:8XqDz5)]
# 10) Clean up after dinner and make sure the cafe looks its best (4:00-5:00pm): [(ID:7JgK7x)]
# 11) Prepare for Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event at 5:00 pm (5:00-6:00pm): [(ID:8JhDy8)]
# 12) Host the Valentine's Day party and welcome customers to Hobbs Cafe (6:00-7:00pm): [(ID:9JhXj1)]
# 13) Clean up after the Valentine's Day party and prepare for closing (7:00-8:00pm): [(ID:8JgK7x)]
# 14) Finish up cleaning tasks and prepare for the next day's opening (8:00-9:00pm): [(ID:3U6sLn)]
# 15) Close Hobbs Cafe at 8:00 pm.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:wPa5Bj) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:5sLEes) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:jB2fp5) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:eNOIqE) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:KmADZS) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:IV9UoE) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:nIZHlN) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:aQVsvM) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:SaBb5F) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.\n[(ID:qZ4gv7) Monday February 13 -- 08:30 AM] Activity: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.\n[(ID:z2W8hM) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.\n[(ID:6Kbz5w) Monday February 13 -- 10:00 AM] Activity: Isabella is working at the counter, taking orders, making drinks, and serving food to customers. She will also assist with cleaning tasks as needed.\n[(ID:2B9V6j) Monday February 13 -- 11:00 AM] Activity: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.\n[(ID:4KzqW7) Monday February 13 -- 12:00 PM] Activity: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after custo ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:wPa5Bj) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:5sLEes) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:jB2fp5) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:eNOIqE) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:KmADZS) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:IV9UoE) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:nIZHlN) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:aQVsvM) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:SaBb5F) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.
# [(ID:qZ4gv7) Monday February 13 -- 08:30 AM] Activity: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.
# [(ID:z2W8hM) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.
# [(ID:6Kbz5w) Monday February 13 -- 10:00 AM] Activity: Isabella is working at the counter, taking orders, making drinks, and serving food to customers. She will also assist with cleaning tasks as needed.
# [(ID:2B9V6j) Monday February 13 -- 11:00 AM] Activity: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.
# [(ID:4KzqW7) Monday February 13 -- 12:00 PM] Activity: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:8XqDz5) Monday February 13 -- 1:00 PM] Activity: Isabella is preparing for dinner by making pastas, pizzas, and other dishes. She will also assist with setting the tables and cleaning up after customers as needed.
# [(ID:9J4B2k) Monday February 13 -- 2:00 PM] Activity: Isabella is serving dinner to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:3U6sLn) Monday February 13 -- 3:00 PM] Activity: Isabella is preparing for closing by cleaning up the kitchen, wiping down counters and tables, and ensuring that everything is in order before closing the cafe at 8:00 pm.
# [(ID:7JgK7x) Monday February 13 -- 4:00 PM] Activity: Isabella is finishing up cleaning tasks and preparing for the next day's opening. She will also take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
# [(ID:8JhDy8) Monday February 13 -- 5:00 PM] Activity: Isabella is preparing for her Valentine's Day party by setting up decorations, preparing food and drink options, and making sure that everything is ready for the event at 5:00 pm.
# [(ID:9JhXj1) Monday February 13 -- 6:00 PM] Activity: Isabella is hosting her Valentine's Day party and welcoming customers to Hobbs Cafe. She will greet guests, serve food and drinks, and ensure that everyone has a great time during the event.
# [(ID:8JgK7x) Monday February 13 -- 7:00 PM] Activity: Isabella is finishing up cleaning up after the Valentine's Day party and preparing for closing. She will make sure that everything is in order before closing the cafe at 8:00 pm.
# [(ID:3U6sLn) Monday February 13 -- 8:00 PM] Activity: Isabella is finishing up closing tasks and preparing for the next day's opening. She will take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
#
# [Isabella Rodriguez's schedule plan requirement: Isabella opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.]
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:6PrMC8) Monday February 13 -- 09:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez's schedule breakdown for Monday, February 13th, 2023 from 9:00am to 7:00pm.
#
# 1) Wake up and complete morning routine (8:00-9:00am): [(ID:6PrMC8)]
# 2) Prepare breakfast for herself and employees (9:00-9:30am): [(ID:z2W8hM)]
# 3) Get ready for work, including makeup and hair styling (9:30-10:00am): [(ID:qZ4gv7)]
# 4) Open Hobbs Cafe and prepare for customers (10:00-11:00am): [(ID:z2W8hM)]
# 5) Work at the counter, taking orders, making drinks, and serving food to customers (11:00am-12:00pm): [(ID:6Kbz5w)]
# 6) Prepare lunch by making sandwiches, soups, and salads (12:00-1:00pm): [(ID:4KzqW7)]
# 7) Clean up after lunch and make sure the cafe looks its best (1:00-2:00pm): [(ID:8XqDz5)]
# 8) Prepare for dinner by making pastas, pizzas, and other dishes (2:00-3:00pm): [(ID:9J4B2k)]
# 9) Serve dinner to customers and assist with ordering and payment (3:00-4:00pm): [(ID:8XqDz5)]
# 10) Clean up after dinner and make sure the cafe looks its best (4:00-5:00pm): [(ID:7JgK7x)]
# 11) Prepare for Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event at 5:00 pm (5:00-6:00pm): [(ID:8JhDy8)]
# 12) Host the Valentine's Day party and welcome customers to Hobbs Cafe (6:00-7:00pm): [(ID:9JhXj1)]
# 13) Clean up after the Valentine's Day party and prepare for closing (7:00-8:00pm): [(ID:8JgK7x)]
# 14) Finish up cleaning tasks and prepare for the next day's opening (8:00-9:00pm): [(ID:3U6sLn)]
# 15) Close Hobbs Cafe at 8:00 pm
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# [Monday February 13 -- 00:00 AM]: Isabella is sleeping
# [Monday February 13 -- 01:00 AM]: Isabella is sleeping
# [Monday February 13 -- 02:00 AM]: Isabella is sleeping
# [Monday February 13 -- 03:00 AM]: Isabella is sleeping
# [Monday February 13 -- 04:00 AM]: Isabella is sleeping
# [Monday February 13 -- 05:00 AM]: Isabella is sleeping
# [Monday February 13 -- 06:00 AM]: Isabella is sleeping
# [Monday February 13 -- 07:00 AM]: Isabella is sleeping
# [Monday February 13 -- 08:00 AM]: Isabella is preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.
# [(ID:z2W8hM) Monday February 13 -- 08:30 AM]: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.
# [(ID:6Kbz5w) Monday February 13 -- 09:00 AM]: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.
# [(ID:2B9V6j) Monday February 13 -- 11:00 AM]: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.
# [(ID:4KzqW7) Monday February 13 -- 12:00 PM]: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:8XqDz5) Monday February 13 -- 1:00 PM]: Isabella is preparing for dinner by making pastas, pizzas, and other dishes. She will also assist with setting the tables and cleaning up after customers as needed.
# [(ID:9J4B2k) Monday February 13 -- 2:00 PM]: Isabella is serving dinner to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:3U6sLn) Monday February 13 -- 3:00 PM]: Isabella is preparing for closing by cleaning up the kitchen, wiping down counters and tables, and ensuring that everything is in order before closing the cafe at 8:00 pm.
# [(ID:7JgK7x) Monday February 13 -- 4:00 PM]: Isabella is finishing up cleaning tasks and preparing for the next day's opening. She will also take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
# [(ID:8JhDy8) Monday February 13 -- 5:00 PM]: Isabella is preparing for her Valentine's Day party by setting up decorations, preparing food and drink options, and making sure that everything is ready for the event at 5:00 pm.
# [(ID:9JhXj1) Monday February 13 -- 6:00 PM]: Isabella is hosting her Valentine's Day party and welcoming customers to Hobbs Cafe. She will greet guests, serve food and drinks, and ensure that everyone has a great time during the event.
# [(ID:8JgK7x) Monday February 13 -- 7:00 PM]: Isabella is finishing up cleaning up after the Valentine's Day party and preparing for closing. She will make sure that everything is in order before closing the cafe at 8:00 pm.
# [(ID:3U6sLn) Monday February 13 -- 8:00 PM]: Isabella is finishing up closing tasks and preparing for the next day's opening. She will take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:jILQk0) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:XNQxLr) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:99hg1I) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:1ImHz5) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:WvzZJg) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:BMC5IO) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:n73APk) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:qkN3XX) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:XUd7VV) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.\n[(ID:qZ4gv7) Monday February 13 -- 08:30 AM] Activity: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.\n[(ID:z2W8hM) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.\n[(ID:6Kbz5w) Monday February 13 -- 10:00 AM] Activity: Isabella is working at the counter, taking orders, making drinks, and serving food to customers. She will also assist with cleaning tasks as needed.\n[(ID:2B9V6j) Monday February 13 -- 11:00 AM] Activity: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.\n[(ID:4KzqW7) Monday February 13 -- 12:00 PM] Activity: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after custo ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:jILQk0) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:XNQxLr) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:99hg1I) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:1ImHz5) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:WvzZJg) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:BMC5IO) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:n73APk) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:qkN3XX) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:XUd7VV) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing breakfast for herself and her employees. She will start the day with a hot cup of coffee, toast with avocado, and scrambled eggs before heading to work.
# [(ID:qZ4gv7) Monday February 13 -- 08:30 AM] Activity: Isabella is finishing up getting ready for work, including putting on makeup and styling her hair. She will then head downstairs to open Hobbs Cafe at 9:00 am.
# [(ID:z2W8hM) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe for the day and preparing for customers. She will take inventory, set up the counter, and greet customers when they arrive.
# [(ID:6Kbz5w) Monday February 13 -- 10:00 AM] Activity: Isabella is working at the counter, taking orders, making drinks, and serving food to customers. She will also assist with cleaning tasks as needed.
# [(ID:2B9V6j) Monday February 13 -- 11:00 AM] Activity: Isabella is preparing for lunch by making sandwiches, soups, and salads. She will also restock the counter with fresh items and clean up any messes.
# [(ID:4KzqW7) Monday February 13 -- 12:00 PM] Activity: Isabella is serving lunch to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:8XqDz5) Monday February 13 -- 1:00 PM] Activity: Isabella is preparing for dinner by making pastas, pizzas, and other dishes. She will also assist with setting the tables and cleaning up after customers as needed.
# [(ID:9J4B2k) Monday February 13 -- 2:00 PM] Activity: Isabella is serving dinner to customers and assisting with ordering and payment. She will also continue to clean up after customers and make sure the cafe is looking its best.
# [(ID:3U6sLn) Monday February 13 -- 3:00 PM] Activity: Isabella is preparing for closing by cleaning up the kitchen, wiping down counters and tables, and ensuring that everything is in order before closing the cafe at 8:00 pm.
# [(ID:7JgK7x) Monday February 13 -- 4:00 PM] Activity: Isabella is finishing up cleaning tasks and preparing for the next day's opening. She will also take inventory, restock supplies, and make any necessary repairs or adjustments to the cafe.
# ...
# ["Isabella Rodriguez has a busy schedule for today, Monday, February 13th, from 9:00 am to 7:00 pm. Her breakdown of activities for the day includes:\n\n9:00-9:30am: Prepare breakfast for herself and employees (ID:z2W8hM)\n9:30-10:00am: Get ready for work, including makeup and hair styling (ID:qZ4gv7)\n10:00-11:00am: Open Hobbs Cafe and prepare for customers (ID:z2W8hM)\n11:00am-12:00pm: Work at the counter, taking orders, making drinks, and serving food to customers (ID:6Kbz5w)\n12:00-1:00pm: Prepare lunch by making sandwiches, soups, and salads (ID:4KzqW7)\n1:00-2:00pm: Clean up after lunch and make sure the cafe looks its best (ID:8XqDz5)\n2:00-3:00pm: Prepare for dinner by making pastas, pizzas, and other dishes (ID:9J4B2k)\n3:00-4:00pm: Serve dinner to customers and assist with ordering and payment (ID:8XqDz5)\n4:00-5:00pm: Clean up after dinner and make sure the cafe looks its best (ID:7JgK7x)\n5:00-6:00pm: Prepare for Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event (ID:8JhDy8)\n6:00-7:00pm: Host the Valentine's Day party and welcome customers to Hobbs Cafe (ID:9JhXj1)\n7:00-8:00pm: Clean up after the Valentine's Day party and prepare for closing (ID:7JgK7x)\n8:00-9:00pm: Finish up cleaning tasks and prepare for the next day's opening (ID:3U6sLn)\nIsabella will wake up at 4:00 pm, but it is not clear what she will do until then", 60]
# ["Isabella Rodriguez is a cafe owner who has a busy schedule for today, Monday, February 13th. She will wake up at 4:00 pm and start her day by completing her morning routine, then preparing breakfast for herself and her employees. From 9:30 am to 10:00 am, Isabella will get ready for work by doing makeup and styling her hair.\n\nFrom 10:00 am to 11:00 am, Isabella will open Hobbs Cafe and prepare for customers by taking orders and making drinks at the counter. From 11:00 am to 12:00 pm, she will continue serving customers and preparing lunch by making sandwiches, soups, and salads.\n\nAfter lunch, from 12:00 pm to 1:00 pm, Isabella will clean up after lunch and make sure the cafe looks its best. From 1:00 pm to 2:00 pm, she will prepare for dinner by making pastas, pizzas, and other dishes.\n\nFrom 2:00 pm to 3:00 pm, Isabella will serve dinner to customers and assist with ordering and payment before cleaning up after dinner. From 3:00 pm to 4:00 pm, she will get ready for the Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event.\n\nFrom 4:00 pm to 5:00 pm, Isabella will host the Valentine's Day party and welcome customers to Hobbs Cafe before cleaning up after the party from 5:00 pm to 6:00 pm. Finally, she will finish up any remaining tasks before closing the cafe for the night from 6:00 pm to 7:00 pm. Isabella will wake up at 4:00 pm, but it is not clear what she will do until then", 60]
# ["Isabella Rodriguez has a busy schedule for today, Monday, February 13th. Here's her breakdown of activities for the day:\n\nFrom 8:00 am to 12:00 pm, Isabella will prepare breakfast and lunch by making sandwiches, soups, salads, pastas, pizzas, and other dishes. She will also clean up after herself and her employees during this time.\n\nFrom 12:00 pm to 2:00 pm, Isabella will open Hobbs Cafe for lunch service. She will take orders and make drinks at the counter, as well as serve food to customers. She will continue cleaning up after lunch during this time.\n\nFrom 2:00 pm to 4:00 pm, Isabella will prepare dinner by making more pastas, pizzas, and other dishes. She will also clean up after dinner and make sure the cafe looks its best.\n\nFrom 4:00 pm to 6:00 pm, Isabella will get ready for the Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event. She will also clean up after dinner during this time.\n\nFrom 6:00 pm to 8:00 pm, Isabella will host the Valentine's Day party and welcome customers to Hobbs Cafe. She will also clean up after the party during this time.\n\nFinally, from 8:00 pm to 9:00 pm, Isabella will finish up cleaning tasks and prepare for the next day's opening by getting ready for bed.\n\nIsabella will wake up at 4:00 pm, but it is not clear what she will do until then", 60]
# ["Isabella Rodriguez, a cafe owner, has a busy schedule on Monday, February 13th. She will wake up at 4:00 pm and start her day by completing her morning routine, then preparing breakfast for herself and her employees. From 9:30 am to 10:00 am, Isabella will get ready for work by doing makeup and styling her hair.\n\nFrom 10:00 am to 11:00 am, she will open Hobbs Cafe and prepare for customers by taking orders and making drinks at the counter. From 11:00 am to 12:00 pm, Isabella will continue serving customers and preparing lunch by making sandwiches, soups, and salads.\n\nAfter lunch, from 12:00 pm to 1:00 pm, Isabella will clean up after lunch and make sure the cafe looks its best. From 1:00 pm to 2:00 pm, she will prepare for dinner by making pastas, pizzas, and other dishes.\n\nFrom 2:00 pm to 3:00 pm, Isabella will serve dinner to customers and assist with ordering and payment before cleaning up after dinner. From 3:00 pm to 4:00 pm, she will get ready for the Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event.\n\nFrom 4:00 pm to 5:00 pm, Isabella will host the Valentine's Day party and welcome customers to Hobbs Cafe before cleaning up after the party from 5:00 pm to 6:00 pm. Finally, she will finish up any remaining tasks before closing the cafe for the night from 6:00 pm to 7:00 pm.\n\nIsabella will wake up at 4:00 pm, but it is not clear what she will do until then", 60]
# ["Isabella Rodriguez has a busy schedule on Monday, February 13th. She will wake up at 4:00 pm and start her day by completing her morning routine, then preparing breakfast for herself and her employees. From 9:30 am to 10:00 am, Isabella will get ready for work by doing makeup and styling her hair.\n\nFrom 10:00 am to 11:00 am, she will open Hobbs Cafe and prepare for customers by taking orders and making drinks at the counter. From 11:00 am to 12:00 pm, Isabella will continue serving customers and preparing lunch by making sandwiches, soups, and salads.\n\nAfter lunch, from 12:00 pm to 1:00 pm, Isabella will clean up after lunch and make sure the cafe looks its best. From 1:00 pm to 2:00 pm, she will prepare for dinner by making pastas, pizzas, and other dishes.\n\nFrom 2:00 pm to 3:00 pm, Isabella will serve dinner to customers and assist with ordering and payment before cleaning up after dinner. From 3:00 pm to 4:00 pm, she will get ready for the Valentine's Day party by setting up decorations, preparing food and drink options, and making sure everything is ready for the event.\n\nFrom 4:00 pm to 5:00 pm, Isabella will host the Valentine's Day party and welcome customers to Hobbs Cafe before cleaning up after the party from 5:00 pm to 6:00 pm. Finally, she will finish up any remaining tasks before closing the cafe for the night from 6:00 pm to 7:00 pm", 60]
# 0
# 16
# Isabella Rodriguez
# ------
# GNS FUNCTION: <generate_action_sector>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez's apartment}.
# DEBUG Harvey Oak Supply Store ------ Isabella Rodriguez's apartment
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', '\nIsabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.', "Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment", 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez']
#
# ~~~ prompt_input    ----------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Isabella Rodriguez lives in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez is currently in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Area options: {Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area: {
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez's apartment
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Problem find !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# GNS FUNCTION: <generate_action_arena>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# bedroom}
# bedroom
# === persona/prompt_template/v1/action_location_object_vMar11.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room']
#
# ~~~ prompt_input    ----------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For cooking, Jane Anderson should go to the following area in Jane Anderson's house:
# Answer: {kitchen}
# ---
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For getting coffee, Tom Watson should go to the following area in Hobbs Cafe:
# Answer: {cafe}
# ---
#
# Now your turn:
# Isabella Rodriguez is going to Isabella Rodriguez's apartment that has the following areas: {main room}
# * Stay in the current area if the activity can be done there.
# * NEVER go into other people's rooms unless necessary.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area in Isabella Rodriguez's apartment :
# Answer: {
#
# ~~~ prompt    ----------------------------------------------------
# bedroom
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Debug: act_address: ???????????????????????????????????????????????????????????????????????????????????????
# the Ville:Isabella Rodriguez's apartment:bedroom
# sleeping
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# bedroom
# bedroom
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 107, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'bedroom'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 633, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 109, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'bedroom'
# Error.
# Enter option:
