# %%
for i in range(1,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand7\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_rm_$i"
# Out:
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'

# %%
for i in range(2,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand2\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_$i"
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 257, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 407, in __func_clean_up
#     duration = int(k[1].split(",")[0].strip())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'x'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'

# %%
! echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# GNS FUNCTION: <generate_wake_up_hour>
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Isabella']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Isabella's wake up hour:
#
# ~~~ prompt    ----------------------------------------------------
# 6
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Monday February 13', 'Isabella', '6:00 am']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Today is Monday February 13. Here is Isabella's plan today in broad-strokes (with the time of the day. e.g., have a lunch at 12:00 pm, watch TV from 7 to 8 pm): 1) wake up and complete the morning routine at 6:00 am, 2)
#
# ~~~ prompt    ----------------------------------------------------
# ['wake up and complete the morning routine at 6:00 am', 'Have breakfast with her family at 7:00 am']
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:TPoYgc) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:zo8DVJ) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:5KEQkV) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:or1DmK) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:cdbuSh) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:1Zn3sx) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am", '', '[(ID:xkHrFk) Monday February 13 -- 06:00 AM] Activity: Isabella is']
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:TPoYgc) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:zo8DVJ) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:5KEQkV) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:or1DmK) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:cdbuSh) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:1Zn3sx) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am
# [(ID:xkHrFk) Monday February 13 -- 06:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez is sleeping
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:b0hch0) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:6Vc16P) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:lV2vYQ) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:4U9zBN) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:JnVrl6) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:Ujp1oD) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:pOpXTQ) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am", '', '[(ID:rNVPyg) Monday February 13 -- 07:00 AM] Activity: Isabella is']
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:b0hch0) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:6Vc16P) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:lV2vYQ) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:4U9zBN) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:JnVrl6) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:Ujp1oD) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:pOpXTQ) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am
# [(ID:rNVPyg) Monday February 13 -- 07:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# having breakfast with her family.
# [(ID:w56h4Z) Monday February 13 -- 08:00 AM] Activity: Isabella opens Hobbs Cafe at 8am.
# [(ID:9V7jTQ) Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe.
# [(ID:6mJlZW) Monday February 13 -- 12:00 PM] Activity: Isabella takes a lunch break at Hobbs Cafe.
# [(ID:qC1gMK) Monday February 13 -- 01:00 PM] Activity: Isabella resumes her work at the counter of Hobbs Cafe.
# [(ID:rV8jTN) Monday February 13 -- 04:00 PM] Activity: Isabella takes a break to gather party material for the Valentine's Day party.
# [(ID:w3f6QF) Monday February 13 -- 05:00 PM] Activity: Isabella starts preparing for the Valentine's Day party at Hobbs Cafe.
# [(ID:k4vHbB) Monday February 13 -- 07:00 PM] Activity: Isabella closes Hobbs Cafe at 7pm, and starts preparing for her own personal Valentine's Day celebration with her family.
# [(ID:zj9W6Z) Monday February 13 -- 08:00 PM] Activity: Isabella completes her personal Valentine's Day celebration with her family, then goes home to bed at around 11pm
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:VFNqkt) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:jj1yBK) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:3iVJni) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:P86gkV) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:MMyYEl) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:YdQw7D) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:pBPP0z) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping\n[(ID:IiKoyQ) Monday February 13 -- 07:00 AM] Activity: Isabella is having breakfast with her family.\n[(ID:w56h4Z) Monday February 13 -- 08:00 AM] Activity: Isabella opens Hobbs Cafe at 8am.\n[(ID:9V7jTQ) Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe.\n[(ID:6mJlZW) Monday February 13 -- 12:00 PM] Activity: Isabella takes a lunch break at Hobbs Cafe.\n[(ID:qC1gMK) Monday February 13 -- 01:00 PM] Activity: Isabella resumes her work at the counter of Hobbs Cafe.\n[(ID:rV8jTN) Monday February 13 -- 04:00 PM] Activity: Isabella takes a break to gather party material for the Valentine's Day party.\n[(ID:w3f6QF) Monday February 13 -- 05:00 PM] Activity: Isabella starts preparing for the Valentine's Day party at Hobbs Cafe.\n[(ID:k4vHbB) Monday February 13 -- 07:00 PM] Activity: Isabella closes Hobbs Cafe at 7pm, and starts preparing for her own personal Valentine's Day celebration with her family.\n[(ID:zj9W6Z) Monday February 13 -- 08:00 PM] Activity: Isabella completes her personal Valentine's Day celebration with her family, then goes home to bed at around 11pm\n\n", "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:VFNqkt) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:jj1yBK) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:3iVJni) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:P86gkV) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:MMyYEl) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:YdQw7D) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:pBPP0z) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping
# [(ID:IiKoyQ) Monday February 13 -- 07:00 AM] Activity: Isabella is having breakfast with her family.
# [(ID:w56h4Z) Monday February 13 -- 08:00 AM] Activity: Isabella opens Hobbs Cafe at 8am.
# [(ID:9V7jTQ) Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe.
# [(ID:6mJlZW) Monday February 13 -- 12:00 PM] Activity: Isabella takes a lunch break at Hobbs Cafe.
# [(ID:qC1gMK) Monday February 13 -- 01:00 PM] Activity: Isabella resumes her work at the counter of Hobbs Cafe.
# [(ID:rV8jTN) Monday February 13 -- 04:00 PM] Activity: Isabella takes a break to gather party material for the Valentine's Day party.
# [(ID:w3f6QF) Monday February 13 -- 05:00 PM] Activity: Isabella starts preparing for the Valentine's Day party at Hobbs Cafe.
# [(ID:k4vHbB) Monday February 13 -- 07:00 PM] Activity: Isabella closes Hobbs Cafe at 7pm, and starts preparing for her own personal Valentine's Day celebration with her family.
# [(ID:zj9W6Z) Monday February 13 -- 08:00 PM] Activity: Isabella completes her personal Valentine's Day celebration with her family, then goes home to bed at around 11pm
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am
# [(ID:uOhQ7b) Monday February 13 -- 08:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# Here's a revised version of Isabella Rodriguez's hourly schedule, in the format you requested:
#
# [Monday February 13 -- 00:00 AM] Activity: Sleeping
# [Monday February 13 -- 01:00 AM] Activity: Sleeping
# [Monday February 13 -- 02:00 AM] Activity: Sleeping
# [Monday February 13 -- 03:00 AM] Activity: Sleeping
# [Monday February 13 -- 04:00 AM] Activity: Sleeping
# [Monday February 13 -- 05:00 AM] Activity: Sleeping
# [Monday February 13 -- 06:00 AM] Activity: Wakes up and completes morning routine
# [Monday February 13 -- 07:00 AM] Activity: Has breakfast with her family
# [Monday February 13 -- 08:00 AM] Activity: Opens Hobbs Cafe at 8am
# [Monday February 13 -- 08:30 AM] Activity: Starts work at the counter of Hobbs Cafe
# [Monday February 13 -- 12:00 PM] Activity: Takes a lunch break at Hobbs Cafe
# [Monday February 13 -- 01:00 PM] Activity: Resumes work at the counter of Hobbs Cafe
# [Monday February 13 -- 04:00 PM] Activity: Takes a break to gather party material for Valentine's Day party
# [Monday February 13 -- 05:00 PM] Activity: Starts preparing for Valentine's Day party at Hobbs Cafe
# [Monday February 13 -- 07:00 PM] Activity: Closes Hobbs Cafe at 7pm, starts preparing for personal Valentine's Day celebration with family
# [Monday February 13 -- 08:00 PM] Activity: Completes personal Valentine's Day celebration with family, goes home to bed at around 11pm
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:3BwgOn) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:0tizuY) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:dvl6oy) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:UbarJI) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:EyYjKp) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:O8MoiN) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:JdVVQJ) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping\n[(ID:e6RFk4) Monday February 13 -- 07:00 AM] Activity: Isabella is having breakfast with her family.\n[(ID:w56h4Z) Monday February 13 -- 08:00 AM] Activity: Isabella opens Hobbs Cafe at 8am.\n[(ID:9V7jTQ) Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe.\n[(ID:6mJlZW) Monday February 13 -- 12:00 PM] Activity: Isabella takes a lunch break at Hobbs Cafe.\n[(ID:qC1gMK) Monday February 13 -- 01:00 PM] Activity: Isabella resumes her work at the counter of Hobbs Cafe.\n[(ID:rV8jTN) Monday February 13 -- 04:00 PM] Activity: Isabella takes a break to gather party material for the Valentine's Day party.\n[(ID:w3f6QF) Monday February 13 -- 05:00 PM] Activity: Isabella starts preparing for the Valentine's Day party at Hobbs Cafe.\n[(ID:k4vHbB) Monday February 13 -- 07:00 PM] Activity: Isabella closes Hobbs Cafe at 7pm, and starts preparing for her own personal Valentine's Day celebration with her family.\n[(ID:zj9W6Z) Monday February 13 -- 08:00 PM] Activity: Isabella completes her personal Valentine's Day celebration with her family, then goes home to bed at around 11pm\n[(ID:0a8vPm) Monday February 13 -- 08:00 AM] Activity: Isabella is Here's a revised version of Isabella Rodriguez's hourly schedule, in the format you requested:\n\n[Monday Februa ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:3BwgOn) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:0tizuY) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:dvl6oy) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:UbarJI) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:EyYjKp) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:O8MoiN) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:JdVVQJ) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping
# [(ID:e6RFk4) Monday February 13 -- 07:00 AM] Activity: Isabella is having breakfast with her family.
# [(ID:w56h4Z) Monday February 13 -- 08:00 AM] Activity: Isabella opens Hobbs Cafe at 8am.
# [(ID:9V7jTQ) Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe.
# [(ID:6mJlZW) Monday February 13 -- 12:00 PM] Activity: Isabella takes a lunch break at Hobbs Cafe.
# [(ID:qC1gMK) Monday February 13 -- 01:00 PM] Activity: Isabella resumes her work at the counter of Hobbs Cafe.
# [(ID:rV8jTN) Monday February 13 -- 04:00 PM] Activity: Isabella takes a break to gather party material for the Valentine's Day party.
# [(ID:w3f6QF) Monday February 13 -- 05:00 PM] Activity: Isabella starts preparing for the Valentine's Day party at Hobbs Cafe.
# [(ID:k4vHbB) Monday February 13 -- 07:00 PM] Activity: Isabella closes Hobbs Cafe at 7pm, and starts preparing for her own personal Valentine's Day celebration with her family.
# [(ID:zj9W6Z) Monday February 13 -- 08:00 PM] Activity: Isabella completes her personal Valentine's Day celebration with her family, then goes home to bed at around 11pm
# [(ID:0a8vPm) Monday February 13 -- 08:00 AM] Activity: Isabella is Here's a revised version of Isabella Rodriguez's hourly schedule, in the format you requested:
#
# [Monday February 13 -- 00:00 AM] Activity: Sleeping
# [Monday February 13 -- 01:00 AM] Activity: Sleeping
# [Monday February 13 -- 02:00 AM] Activity: Sleeping
# [Monday February 13 -- 03:00 AM] Activity: Sleeping
# [Monday February 13 -- 04:00 AM] Activity: Sleeping
# [Monday February 13 -- 05:00 AM] Activity: Sleeping
# [Monday February 13 -- 06:00 AM] Activity: Wakes up and completes morning routine
# [Monday February 13 -- 07:00 AM] Activity: Has breakfast with her family
# [Monday February 13 -- 08:00 AM] Activity: Opens Hobbs Cafe at 8am
# [Monday February 13 -- 08:30 AM] Activity: Starts work at the counter of Hobbs Cafe
# [Monday February 13 -- 12:00 PM] Activity: Takes a lunch break at Hobbs Cafe
# [Monday February 13 -- 01:00 PM] Activity: Resumes work at the counter of Hobbs Cafe
# [Monday February 13 -- 04:00 PM] Activity: Takes a break to gather party material for Valentine's Day party
# [Monday February 13 -- 05:00 PM] Activity: Starts preparing for Valentine's Day party at Hobbs Cafe
# [Monday February 13 -- 07:00 PM] Activity: Closes Hobbs Cafe at 7pm, starts preparing for personal Valentine's Day celebration with family
# [Monday February 13 -- 08:00 PM] Activity: Completes personal Valentine's Day celebration with family, goes home to bed at around 11pm
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am
# [(ID:WwIGqV) Monday February 13 -- 09:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# [Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe
# [Monday February 13 -- 12:00 PM] Activity: Takes a lunch break at Hobbs Cafe
# [Monday February 13 -- 01:00 PM] Activity: Resumes work at the counter of Hobbs Cafe
# [Monday February 13 -- 04:00 PM] Activity: Takes a break to gather party material for Valentine's Day party
# [Monday February 13 -- 05:00 PM] Activity: Starts preparing for Valentine's Day party at Hobbs Cafe
# [Monday February 13 -- 06:00 PM] Activity: Closes Hobbs Cafe at 6pm, goes home to get ready for her personal Valentine's Day celebration with family
# [Monday February 13 -- 07:00 PM] Activity: Starts preparing for her personal Valentine's Day celebration with family
# [Monday February 13 -- 08:00 PM] Activity: Completes her personal Valentine's Day celebration with family, then goes home to bed at around 11pm
#
# Note that there is no activity listed for Sunday February 12th and Tuesday February 14th
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:CpIHYY) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:xEA7Wj) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:FAmpbF) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:U5v6Mq) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:DN05XM) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:fICrD5) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:n4DI9Y) Monday February 13 -- 06:00 AM] Activity: Isabella is Isabella Rodriguez is sleeping\n[(ID:wDuvoq) Monday February 13 -- 07:00 AM] Activity: Isabella is having breakfast with her family.\n[(ID:w56h4Z) Monday February 13 -- 08:00 AM] Activity: Isabella opens Hobbs Cafe at 8am.\n[(ID:9V7jTQ) Monday February 13 -- 08:30 AM] Activity: Isabella starts her work at the counter of Hobbs Cafe.\n[(ID:6mJlZW) Monday February 13 -- 12:00 PM] Activity: Isabella takes a lunch break at Hobbs Cafe.\n[(ID:qC1gMK) Monday February 13 -- 01:00 PM] Activity: Isabella resumes her work at the counter of Hobbs Cafe.\n[(ID:rV8jTN) Monday February 13 -- 04:00 PM] Activity: Isabella takes a break to gather party material for the Valentine's Day party.\n[(ID:w3f6QF) Monday February 13 -- 05:00 PM] Activity: Isabella starts preparing for the Valentine's Day party at Hobbs Cafe.\n[(ID:k4vHbB) Monday February 13 -- 07:00 PM] Activity: Isabella closes Hobbs Cafe at 7pm, and starts preparing for her own personal Valentine's Day celebration with her family.\n[(ID:zj9W6Z) Monday February 13 -- 08:00 PM] Activity: Isabella completes her personal Valentine's Day celebration with her family, then goes home to bed at around 11pm\n[(ID:0lMQ6i) Monday February 13 -- 08:00 AM] Activity: Isabella is Here's a revised version of Isabella Rodriguez's hourly schedule, in the format you requested:\n\n[Monday Februa ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# ...
# ["Here is an hourly breakdown of Isabella's schedule on Monday, February 13th, 2023:\n\n* 7:00 AM - Wake up and complete morning routine\n* 8:00 AM - Have breakfast with her family\n* 9:00 AM - Take a break to gather party material for Valentine's Day party\n* 10:00 AM - Prepare for Valentine's Day party at Hobbs Cafe\n* 12:00 PM - Take a lunch break at Hobbs Cafe\n* 1:00 PM - Resume work at the counter of Hobbs Cafe\n* 2:00 PM - Take a break to gather more party material for Valentine's Day party\n* 3:00 PM - Prepare for Valentine's Day party at Hobbs Cafe\n* 4:00 PM - Take a break to gather more party material for Valentine's Day party\n* 5:00 PM - Prepare for Valentine's Day party at Hobbs Cafe\n* 6:00 PM - Close Hobbs Cafe and prepare for personal Valentine's Day celebration with family\n* 7:00 PM - Start preparing for personal Valentine's Day celebration with family\n* 8:00 PM - Complete personal Valentine's Day celebration with family and goes home to bed", 60]
# ["Here's the hourly breakdown of Isabella Rodriguez's schedule on Monday, February 13th, 2023:\n\n7:00 AM - Wake up and complete morning routine\n8:00 AM - Have breakfast with her family\n9:00 AM - Take a break to gather party material for Valentine's Day party\n10:00 AM - Prepare for Valentine's Day party at Hobbs Cafe\n12:00 PM - Take a lunch break at Hobbs Cafe\n1:00 PM - Resume work at the counter of Hobbs Cafe\n2:00 PM - Take a break to gather more party material for Valentine's Day party\n3:00 PM - Prepare for Valentine's Day party at Hobbs Cafe\n4:00 PM - Take a break to gather more party material for Valentine's Day party\n5:00 PM - Prepare for Valentine's Day party at Hobbs Cafe\n6:00 PM - Close Hobbs Cafe and prepare for personal Valentine's Day celebration with family\n7:00 PM - Start preparing for personal Valentine's Day celebration with family\n8:00 PM - Complete personal Valentine's Day celebration with family and goes home to bed", 60]
# ["Is it possible to continue the hourly breakdown of Isabella's schedule?", 60]
# ["Isabella's schedule on Monday, February 13th, 2023 from 6:00 pm to 8:00 pm:\n\n* 6:00 pm: Close Hobbs Cafe and prepare for personal Valentine's Day celebration with family\n* 7:00 pm: Start preparing for personal Valentine's Day celebration with family\n* 8:00 pm: Complete personal Valentine's Day celebration with family and goes home to bed", 60]
# ["Based on the provided information, Isabella Rodriguez's hourly schedule for Monday, February 13th, 2023 is as follows:\n\n6:00 am - Wake up and complete morning routine.\n7:00 am - Have breakfast with her family.\n9:00 am - Take a break to gather party material for Valentine's Day party.\n10:00 am - Prepare for Valentine's Day party at Hobbs Cafe.\n12:00 pm - Take a lunch break at Hobbs Cafe.\n1:00 pm - Resume work at the counter of Hobbs Cafe.\n2:00 pm - Take a break to gather more party material for Valentine's Day party.\n3:00 pm - Prepare for Valentine's Day party at Hobbs Cafe.\n4:00 pm - Take a break to gather more party material for Valentine's Day party.\n5:00 pm - Prepare for Valentine's Day party at Hobbs Cafe.\n6:00 pm - Close Hobbs Cafe and prepare for personal Valentine's Day celebration with family.\n7:00 pm - Start preparing for personal Valentine's Day celebration with family.\n8:00 pm - Complete personal Valentine's Day celebration with family and goes home to bed", 60]
# ["Isabella's schedule for Monday, February 13th, 2023 from 8:00 pm to 10:00 pm, including the time she spends completing her personal Valentine's Day celebration with her family", 60]
# ["Based on the provided information, Isabella Rodriguez's hourly schedule for Monday, February 13th, 2023 from 9:00 pm to 10:00 pm includes her personal Valentine's Day celebration with her family", 60]
# ["Based on the provided information, Isabella Rodriguez's hourly schedule for Monday, February 13th, 2023 from 10:00 pm to 12:00 am is as follows:\n\n* 10:00 pm - Complete personal Valentine's Day celebration with family\n* 12:00 pm - Goes home to bed\n[(ID:r7ZJnH) Tuesday February 14th -- 11:00 AM] Activity: Isabella is Isabella's schedule for Tuesday, February 14th, 2023 in the format you requested:\n\n[Tuesday February 14th -- 07:00 AM] Activity: Wake up and complete morning routine.\n[Tuesday February 14th -- 08:00 AM] Activity: Have breakfast with her family.\n[Tuesday February 14th -- 09:00 AM] Activity: Take a break to gather party material for Valentine's Day party.\n[Tuesday February 14th -- 10:00 AM] Activity: Prepare for Valentine's Day party at Hobbs Cafe.\n[Tuesday February 14th -- 12:00 PM] Activity: Take a lunch break at Hobbs Cafe.\n[Tuesday February 14th -- 01:00 PM] Activity: Resume work at the counter of Hobbs Cafe.\n[Tuesday February 14th -- 03:00 PM] Activity: Take a break to gather more party material for Valentine's Day party.\n[Tuesday February 14th -- 04:00 PM] Activity: Prepare for Valentine's Day party at Hobbs Cafe.\n[Tuesday February 14th -- 06:00 PM] Activity: Close Hobbs Cafe and prepare for personal Valentine's Day celebration with family.\n[Tuesday February 14th -- 07:00 PM] Activity: Start preparing for personal Valentine's Day celebration with family.\n[Tuesday February 14th -- 08:00 PM] Activity: Complete personal Valentine's Day celebration with family and goes home to bed.\n[(ID:1nLwk9) Tuesday February 14th -- 09:00 PM] Activity: Isabella is Based on the provided information, Isabella Rodriguez's hourly schedule for Tuesday, February 14th, 2023 from 9:00 pm to 10:00 pm, including the time she spends completing her personal Valentine's Day celebration with her family\n\n\nHere the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 6:00 am, 2) Have breakfast with her family at 7:00 am", 60]
# ["Based on the provided information, Isabella's schedule for Monday, February 13th, 2023 from 7:00 pm to 10:00 pm includes the time she spends preparing and completing her personal Valentine's Day celebration with her family.\nIt is not clear what specific activities are included in the preparation and completion of this celebration, but it would likely involve spending time with her family members, perhaps exchanging gifts or cards, sharing special meals or treats, and engaging in other meaningful activities together.\nIt is important to remember that Isabella's schedule may be subject to change if unexpected events arise or if she needs to adjust her plans, but this information should provide a general idea of her activities on this day", 60]
# 0
# 19
# Isabella Rodriguez
# ------
# GNS FUNCTION: <generate_action_sector>
# DEBUG Johnson Park ------ Isabella Rodriguez's apartment
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', '\nIsabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.', "Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment", 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez']
#
# ~~~ prompt_input    ----------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Isabella Rodriguez lives in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez is currently in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Area options: {Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area: {
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez's apartment
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Problem find !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# GNS FUNCTION: <generate_action_arena>
# to see way it is not passing validation ????????????????????????????????????
#  main room}
# ---
# Oliver Brown is in his bedroom in Oliver Brown's house.
# Oliver Brown is going to Oliver Brown's office that has the following areas: {office,  kitchen, bedroom}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For working, Oliver Brown should go to the following area in Oliver Brown's office (MUST pick one of {office,  kitchen, bedroom}):
# Answer: {office}}
# Not pass validation 3 ????????????????????????????????????
#  main room}
# ---
# Oliver Brown is in his bedroom in Oliver Brown's house.
# Oliver Brown is going to Oliver Brown's office that has the following areas: {office,  kitchen, bedroom}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For working, Oliver Brown should go to the following area in Oliver Brown's office (MUST pick one of {office,  kitchen, bedroom}):
# Answer: {office}}
# to see way it is not passing validation ????????????????????????????????????
#  main\_room}
#  main\_room
# === persona/prompt_template/v1/action_location_object_vMar11.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room']
#
# ~~~ prompt_input    ----------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For cooking, Jane Anderson should go to the following area in Jane Anderson's house:
# Answer: {kitchen}
# ---
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For getting coffee, Tom Watson should go to the following area in Hobbs Cafe:
# Answer: {cafe}
# ---
#
# Isabella Rodriguez is going to Isabella Rodriguez's apartment that has the following areas: {main room}
# * Stay in the current area if the activity can be done there.
# * NEVER go into other people's rooms unless necessary.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area in Isabella Rodriguez's apartment (MUST pick one of {main room}):
# Answer: {
#
# ~~~ prompt    ----------------------------------------------------
#  main\_room
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Debug: act_address: ???????????????????????????????????????????????????????????????????????????????????????
# the Ville:Isabella Rodriguez's apartment: main\_room
# sleeping
# GNS FUNCTION: <generate_action_game_object>
#  main\_room
# main\_room
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 107, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'main\\_room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 633, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 109, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'main\\_room'
# Error.
# Enter option:
