# %%
for i in range(1,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand7\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_rm_$i"
# Out:
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'

# %%
for i in range(2,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand2\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_$i"
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 257, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 407, in __func_clean_up
#     duration = int(k[1].split(",")[0].strip())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'x'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'

# %%
! echo -e "base_the_ville_isabella_maria_klaus \n rand2\n run 1\nexit" | python3 reverie.py
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# GNS FUNCTION: <generate_wake_up_hour>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez typically wakes up around 6am every morning.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez usually wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez typically wakes up at 6am every morning.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez typically wakes up at 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez typically wakes up at 6am.
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Isabella']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Isabella's wake up hour:
#
# ~~~ prompt    ----------------------------------------------------
# 8
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  She plans on opening Hobbs Cafe at 9am today and working until 6pm.
# 3) After closing the cafe, she plans on going to bed at 8pm.
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Monday February 13', 'Isabella', '8:00 am']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Today is Monday February 13. Here is Isabella's plan today in broad-strokes (with the time of the day. e.g., have a lunch at 12:00 pm, watch TV from 7 to 8 pm): 1) wake up and complete the morning routine at 8:00 am, 2)
#
# ~~~ prompt    ----------------------------------------------------
# ['wake up and complete the morning routine at 8:00 am', 'She plans on opening Hobbs Cafe at 9am today and working until 6pm']
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  completing her morning routine.
# [(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.
# [(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.
# [(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.
# [(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.
# [(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.
# [(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.
# [(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabella cleans up after the Valentine's Day party at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 8:00 PM] Activity: Isabella closes Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 9:00 PM] Activity: Isabella goes to bed.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:s4to3g) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:iBTw0n) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:WVjvKu) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:Pyfsbr) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:OgP9vR) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:Q1zUmu) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:NefchS) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:UQnAcl) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) She plans on opening Hobbs Cafe at 9am today and working until 6pm", '', '[(ID:Xcm0ET) Monday February 13 -- 08:00 AM] Activity: Isabella is']
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:s4to3g) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:iBTw0n) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:WVjvKu) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:Pyfsbr) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:OgP9vR) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:Q1zUmu) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:NefchS) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:UQnAcl) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) She plans on opening Hobbs Cafe at 9am today and working until 6pm
# [(ID:Xcm0ET) Monday February 13 -- 08:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# completing her morning routine.
# [(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.
# [(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.
# [(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.
# [(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.
# [(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.
# [(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.
# [(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabella cleans up after the Valentine's Day party at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 8:00 PM] Activity: Isabella closes Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 9:00 PM] Activity: Isabella goes to bed
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  The hourly schedule format for Monday, February 13th includes the following activities:
#
# * 00:00 AM: Isabella Rodriguez is sleeping.
# * 01:00 AM: Isabella Rodriguez is sleeping.
# * 02:00 AM: Isabella Rodriguez is sleeping.
# * 03:00 AM: Isabella Rodriguez is sleeping.
# * 04:00 AM: Isabella Rodriguez is sleeping.
# * 05:00 AM: Isabella Rodriguez is sleeping.
# * 06:00 AM: Isabella Rodriguez is sleeping.
# * 07:00 AM: Isabella Rodriguez is sleeping.
# * 08:00 AM: Isabella Rodriguez completes her morning routine.
# * 09:00 AM: Isabella Rodriguez opens Hobbs Cafe.
# * 10:00 AM: Isabella Rodriguez serves customers at Hobbs Cafe.
# * 11:00 AM: Isabella Rodriguez cleans and prepares for lunch service at Hobbs Cafe.
# * 12:00 PM: Isabella Rodriguez serves lunch customers at Hobbs Cafe.
# * 01:00 PM: Isabella Rodriguez cleans and prepares for afternoon service at Hobbs Cafe.
# * 02:00 PM: Isabella Rodriguez serves afternoon customers at Hobbs Cafe.
# * 03:00 PM: Isabella Rodriguez cleans and prepares for dinner service at Hobbs Cafe.
# * 04:00 PM: Isabella Rodriguez serves dinner customers at Hobbs Cafe.
# * 05:00 PM: Isabella Rodriguez prepares for the Valentine's Day party at Hobbs Cafe.
# * 06:00 PM: Isabella Rodriguez serves customers at the Valentine's Day party at Hobbs Cafe.
# * 07:00 PM: Isabella Rodriguez cleans up after the Valentine's Day party at Hobbs Cafe.
# * 08:00 PM: Isabella Rodriguez closes Hobbs Cafe.
# * 09:00 PM: Isabella Rodriguez goes to bed.
#
# It seems that Isabella has planned for a busy day, with a lot of work at Hobbs Cafe and preparing for the Valentine's Day party.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:ovcUho) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:UwQg8a) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:UiLPLX) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:cKTRq0) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:vpocun) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:nv2cMw) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:kjZUvd) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:Am1xoh) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:8ex6ih) Monday February 13 -- 08:00 AM] Activity: Isabella is completing her morning routine.\n[(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.\n[(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.\n[(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.\n[(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.\n[(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.\n[(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.\n[(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.\n[(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.\n[(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.\n[(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.\n[(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabel ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:ovcUho) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:UwQg8a) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:UiLPLX) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:cKTRq0) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:vpocun) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:nv2cMw) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:kjZUvd) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:Am1xoh) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:8ex6ih) Monday February 13 -- 08:00 AM] Activity: Isabella is completing her morning routine.
# [(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.
# [(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.
# [(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.
# [(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.
# [(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.
# [(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.
# [(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabella cleans up after the Valentine's Day party at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 8:00 PM] Activity: Isabella closes Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 9:00 PM] Activity: Isabella goes to bed
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) She plans on opening Hobbs Cafe at 9am today and working until 6pm
# [(ID:QCQLhG) Monday February 13 -- 09:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# The hourly schedule format for Monday, February 13th includes the following activities:
#
# * 00:00 AM: Isabella Rodriguez is sleeping.
# * 01:00 AM: Isabella Rodriguez is sleeping.
# * 02:00 AM: Isabella Rodriguez is sleeping.
# * 03:00 AM: Isabella Rodriguez is sleeping.
# * 04:00 AM: Isabella Rodriguez is sleeping.
# * 05:00 AM: Isabella Rodriguez is sleeping.
# * 06:00 AM: Isabella Rodriguez is sleeping.
# * 07:00 AM: Isabella Rodriguez is sleeping.
# * 08:00 AM: Isabella Rodriguez completes her morning routine.
# * 09:00 AM: Isabella Rodriguez opens Hobbs Cafe.
# * 10:00 AM: Isabella Rodriguez serves customers at Hobbs Cafe.
# * 11:00 AM: Isabella Rodriguez cleans and prepares for lunch service at Hobbs Cafe.
# * 12:00 PM: Isabella Rodriguez serves lunch customers at Hobbs Cafe.
# * 01:00 PM: Isabella Rodriguez cleans and prepares for afternoon service at Hobbs Cafe.
# * 02:00 PM: Isabella Rodriguez serves afternoon customers at Hobbs Cafe.
# * 03:00 PM: Isabella Rodriguez cleans and prepares for dinner service at Hobbs Cafe.
# * 04:00 PM: Isabella Rodriguez serves dinner customers at Hobbs Cafe.
# * 05:00 PM: Isabella Rodriguez prepares for the Valentine's Day party at Hobbs Cafe.
# * 06:00 PM: Isabella Rodriguez serves customers at the Valentine's Day party at Hobbs Cafe.
# * 07:00 PM: Isabella Rodriguez cleans up after the Valentine's Day party at Hobbs Cafe.
# * 08:00 PM: Isabella Rodriguez closes Hobbs Cafe.
# * 09:00 PM: Isabella Rodriguez goes to bed.
#
# It seems that Isabella has planned for a busy day, with a lot of work at Hobbs Cafe and preparing for the Valentine's Day party
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez is the owner of Hobbs Cafe. She plans on having a Valentine's Day party at her cafe on February 14th, 2023 from 5pm to 7pm. Her daily routine includes opening Hobbs Cafe at 8am and working until 6pm.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:ar4H5b) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:TMPIAb) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:Kkw01z) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:YiUlE2) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:7E3wgF) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:tgPH8U) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:FsJ9Yh) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:KBbo1m) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:yTjBtI) Monday February 13 -- 08:00 AM] Activity: Isabella is completing her morning routine.\n[(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.\n[(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.\n[(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.\n[(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.\n[(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.\n[(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.\n[(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.\n[(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.\n[(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.\n[(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.\n[(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabel ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:ar4H5b) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:TMPIAb) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:Kkw01z) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:YiUlE2) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:7E3wgF) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:tgPH8U) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:FsJ9Yh) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:KBbo1m) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:yTjBtI) Monday February 13 -- 08:00 AM] Activity: Isabella is completing her morning routine.
# [(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.
# [(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.
# [(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.
# [(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.
# [(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.
# [(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.
# [(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.
# [(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabella cleans up after the Valentine's Day party at Hobbs Cafe.
# [(ID:NxjK0S) Monday February 13 -- 8:00 PM] Activity: Isabella closes Hobbs Cafe.
# [(ID:M9xN9O) Monday February 13 -- 9:00 PM] Activity: Isabella goes to bed
# [(ID:AdllGU) Monday February 13 -- 09:00 AM] Activity: Isabella is The hourly schedule format for Monday, February 13th includes the following activities:
#
# * 00:00 AM: Isabella Rodriguez is sleeping.
# * 01:00 AM: Isabella Rodriguez is sleeping.
# * 02:00 AM: Isabella Rodriguez is sleeping.
# * 03:00 AM: Isabella Rodriguez is sleeping.
# * 04:00 AM: Isabella Rodriguez is sleeping.
# * 05:00 AM: Isabella Rodriguez is sleeping.
# * 06:00 AM: Isabella Rodriguez is sleeping.
# * 07:00 AM: Isabella Rodriguez is sleeping.
# * 08:00 AM: Isabella Rodriguez completes her morning routine.
# * 09:00 AM: Isabella Rodriguez opens Hobbs Cafe.
# * 10:00 AM: Isabella Rodriguez serves customers at Hobbs Cafe.
# * 11:00 AM: Isabella Rodriguez cleans and prepares for lunch service at Hobbs Cafe.
# * 12:00 PM: Isabella Rodriguez serves lunch customers at Hobbs Cafe.
# * 01:00 PM: Isabella Rodriguez cleans and prepares for afternoon service at Hobbs Cafe.
# * 02:00 PM: Isabella Rodriguez serves afternoon customers at Hobbs Cafe.
# * 03:00 PM: Isabella Rodriguez cleans and prepares for dinner service at Hobbs Cafe.
# * 04:00 PM: Isabella Rodriguez serves dinner customers at Hobbs Cafe.
# * 05:00 PM: Isabella Rodriguez prepares for the Valentine's Day party at Hobbs Cafe.
# * 06:00 PM: Isabella Rodriguez serves customers at the Valentine's Day party at Hobbs Cafe.
# * 07:00 PM: Isabella Rodriguez cleans up after the Valentine's Day party at Hobbs Cafe.
# * 08:00 PM: Isabella Rodriguez closes Hobbs Cafe.
# * 09:00 PM: Isabella Rodriguez goes to bed.
#
# It seems that Isabella has planned for a busy day, with a lot of work at Hobbs Cafe and preparing for the Valentine's Day party
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am, 2) She plans on opening Hobbs Cafe at 9am today and working until 6pm
# [(ID:cKolSc) Monday February 13 -- 10:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez is the owner of Hobbs Cafe. She plans on having a Valentine's Day party at her cafe on February 14th, 2023 from 5pm to 7pm. Her daily routine includes opening Hobbs Cafe at 8am and working until 6pm
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  It seems that there was a mistake in the hourly schedule format for Monday, February 13th. The correct hourly breakdown should be:
#
# * 00:00 AM - Isabella Rodriguez is sleeping
# * 01:00 AM - Isabella Rodriguez is sleeping
# * 02:00 AM - Isabella Rodriguez is sleeping
# * 03:00 AM - Isabella Rodriguez is sleeping
# * 04:00 AM - Isabella Rodriguez is sleeping
# * 05:00 AM - Isabella Rodriguez is sleeping
# * 06:00 AM - Isabella Rodriguez is sleeping
# * 07:00 AM - Isabella Rodriguez is sleeping
# * 08:00 AM - Isabella Rodriguez completes her morning routine.
# * 09:00 AM - Isabella Rodriguez opens Hobbs Cafe.
# * 10:00 AM - Isabella Rodriguez serves customers at Hobbs Cafe.
# * 11:00 AM - Isabella Rodriguez cleans and prepares for lunch service at Hobbs Cafe.
# * 12:00 PM - Isabella Rodriguez serves lunch customers at Hobbs Cafe.
# * 01:00 PM - Isabella Rodriguez cleans and prepares for afternoon service at Hobbs Cafe.
# * 02:00 PM - Isabella Rodriguez serves afternoon customers at Hobbs Cafe.
# * 03:00 PM - Isabella Rodriguez cleans and prepares for dinner service at Hobbs Cafe.
# * 04:00 PM - Isabella Rodriguez serves dinner customers at Hobbs Cafe.
# * 05:00 PM - Isabella Rodriguez prepares for the Valentine's Day party at Hobbs Cafe.
# * 06:00 PM - Isabella Rodriguez serves customers at the Valentine's Day party at Hobbs Cafe.
# * 07:00 PM - Isabella Rodriguez cleans up after the Valentine's Day party at Hobbs Cafe.
# * 08:00 PM - Isabella Rodriguez closes Hobbs Cafe.
# * 09:00 PM - Isabella Rodriguez goes to bed.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:z2aSpE) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:l2S35s) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:P1GLov) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:TjMLmI) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:bxRkp9) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:wqaL4f) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:E4uEp6) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:l5Zlzm) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:JPJeZk) Monday February 13 -- 08:00 AM] Activity: Isabella is completing her morning routine.\n[(ID:CmW7zT) Monday February 13 -- 09:00 AM] Activity: Isabella opens Hobbs Cafe.\n[(ID:WjPjqB) Monday February 13 -- 10:00 AM] Activity: Isabella serves customers at Hobbs Cafe.\n[(ID:E9xJ7X) Monday February 13 -- 11:00 AM] Activity: Isabella cleans and prepares for lunch service at Hobbs Cafe.\n[(ID:V7jK2h) Monday February 13 -- 12:00 PM] Activity: Isabella serves lunch customers at Hobbs Cafe.\n[(ID:M9xN9O) Monday February 13 -- 1:00 PM] Activity: Isabella cleans and prepares for afternoon service at Hobbs Cafe.\n[(ID:C6wK2X) Monday February 13 -- 2:00 PM] Activity: Isabella serves afternoon customers at Hobbs Cafe.\n[(ID:NxjK0S) Monday February 13 -- 3:00 PM] Activity: Isabella cleans and prepares for dinner service at Hobbs Cafe.\n[(ID:I9P7zT) Monday February 13 -- 4:00 PM] Activity: Isabella serves dinner customers at Hobbs Cafe.\n[(ID:WjhQ6O) Monday February 13 -- 5:00 PM] Activity: Isabella prepares for Valentine's Day party at Hobbs Cafe.\n[(ID:J9xP7zT) Monday February 13 -- 6:00 PM] Activity: Isabella serves customers at the Valentine's Day party at Hobbs Cafe.\n[(ID:E9xJ7X) Monday February 13 -- 7:00 PM] Activity: Isabel ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ...
# ["It seems like Isabella Rodriguez has planned her daily schedule for Monday, February 13th, 2023. She plans on waking up at 8:00 am and completing her morning routine before opening Hobbs Cafe at 9:00 am. She intends to work until 6:00 pm serving customers at Hobbs Cafe. Her schedule includes serving lunch from 12:00 pm to 1:00 pm, cleans and prepares for afternoon service from 1:00 pm to 2:00 pm, serves afternoon customers from 2:00 pm to 3:00 pm, cleans and prepares for dinner service from 3:00 pm to 4:00 pm, serves dinner customers from 4:00 pm to 5:00 pm, prepares for the Valentine's Day party from 5:00 pm to 6:00 pm, and serves customers at the party from 6:00 pm to 7:00 pm. After the party, she plans on cleaning up and closing Hobbs Cafe at 8:00 pm before going to bed at 9:00 pm", 60]
# 0
# 17
# Isabella Rodriguez
# ------
# GNS FUNCTION: <generate_action_sector>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  To continue this task, I will need more information about what activity Sam Kim and Jane Anderson want to do in their respective areas. Please provide me with the specific tasks they need to accomplish, and I will suggest an appropriate area for each.
# type 2 error in line 602```````````````````````````````````````````````````````````
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Isabella Rodriguez's apartment}
# DEBUG Hobbs Cafe ------ Isabella Rodriguez's apartment
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', '\nIsabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.', "Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment", 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez']
#
# ~~~ prompt_input    ----------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Isabella Rodriguez lives in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez is currently in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Area options: {Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area: {
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez's apartment
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Problem find !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# GNS FUNCTION: <generate_action_arena>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  main room}
#  main room
# === persona/prompt_template/v1/action_location_object_vMar11.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room']
#
# ~~~ prompt_input    ----------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For cooking, Jane Anderson should go to the following area in Jane Anderson's house:
# Answer: {kitchen}
# ---
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For getting coffee, Tom Watson should go to the following area in Hobbs Cafe:
# Answer: {cafe}
# ---
#
# Isabella Rodriguez is going to Isabella Rodriguez's apartment that has the following areas: {main room}
# * Stay in the current area if the activity can be done there.
# * NEVER go into other people's rooms unless necessary.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area in Isabella Rodriguez's apartment (MUST pick one of {main room}):
# Answer: {
#
# ~~~ prompt    ----------------------------------------------------
#  main room
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Debug: act_address: ???????????????????????????????????????????????????????????????????????????????????????
# the Ville:Isabella Rodriguez's apartment: main room
# sleeping
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
#  main room
# main room
# Identified?????????????????????????????????????/
#  main room
# main room
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  bed
# Identified?????????????????????????????????????/
#  main room
# main room
# === persona/prompt_template/v1/action_object_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['sleeping', 'bed, desk, refrigerator, closet, shelf']
#
# ~~~ prompt_input    ----------------------------------------------
# Current activity: sleep in bed
# Objects available: {bed, easel, closet, painting}
# Pick ONE most relevant object from the objects available: bed
# ---
# Current activity: painting
# Objects available: {easel, closet, sink, microwave}
# Pick ONE most relevant object from the objects available: easel
# ---
# Current activity: cooking
# Objects available: {stove, sink, fridge, counter}
# Pick ONE most relevant object from the objects available: stove
# ---
# Current activity: watch TV
# Objects available: {couch, TV, remote, coffee table}
# Pick ONE most relevant object from the objects available: TV
# ---
# Current activity: study
# Objects available: {desk, computer, chair, bookshelf}
# Pick ONE most relevant object from the objects available: desk
# ---
# Current activity: talk on the phone
# Objects available: {phone, charger, bed, nightstand}
# Pick ONE most relevant object from the objects available: phone
# ---
# Current activity: sleeping
# Objects available: {bed, desk, refrigerator, closet, shelf}
# Pick ONE most relevant object from the objects available:
#
# ~~~ prompt    ----------------------------------------------------
# bed
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: sleeping
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 🛏
# output1___________________________
# 🛏
# GNS FUNCTION: <generate_action_event_triple>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Input: Sam Johnson is eating breakfast.
# Output: (Sam Johnson, is eating, breakfast)
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  is, sleep)
# ---
# Input: Gregory Evans is playing soccer with his friends.
# Output: (Gregory Evans, play, soccer)
# ---
# Input: Rachel Wood is listening to music on headphones.
# Output: (Rachel Wood, listen, music)
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', 'sleeping', 'Isabella Rodriguez']
#
# ~~~ prompt_input    ----------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: Isabella Rodriguez is sleeping.
# Output: (Isabella Rodriguez,
#
# ~~~ prompt    ----------------------------------------------------
# ('Isabella Rodriguez', 'is', 'sleep')
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_act_obj_desc>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 6
# CHAT GPT PROMPT
# """
# Task: We want to understand the state of an object that is being used by someone.
#
# Example 1:
# ---
# Kelly is writing in the desk
# desk is: in using
# ---
# Example 2:
# ---
# Jason is fixing the TV
# Tv is: in fixing
# ---
#
# Now, We want to know about bed's state.
# Isabella Rodriguez is sleeping with the bed.
# bed is:
# """
# Output the response to the prompt above in json. The output should ONLY contain the phrase that should go in <fill in>.
# Example output json:
# {"output": "being fixed"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ---- repeat count:
#  0
#
# ~~~~
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# in using
# output2___________________________
# in using
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: in using
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# output1___________________________
# False
# GNS FUNCTION: <generate_act_obj_event_triple>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  is using])
# ---
# Input: The sky is clear blue.
# Output: (sky, be, clear blue)
# ---
# Input: Mary Smith is reading a book.
# Output: (Mary Smith, read, book)
# ---
# Input: The dog is playing with the ball.
# Output: (dog, play, ball)
# ---
# Input: The sun is setting over the horizon.
# Output: (sun, set, horizon)
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  use, )
# Error: "in" is not a valid preposition for an object.
# To turn the input into (subject, predicate, object), we need to identify the subject, predicate, and object of each sentence. The subject is the person or thing that performs the action or state of being, the predicate is the verb phrase that describes the action or state, and the object is the person or thing that receives the action or is affected by it.
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['bed', 'in using', 'bed']
#
# ~~~ prompt_input    ----------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: bed is in using.
# Output: (bed,
#
# ~~~ prompt    ----------------------------------------------------
# ('bed', 'use', '')
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Isabella Rodriguez persona.scratch.importance_trigger_curr:: 144
# 150
# aldhfoaf/????
# the Ville:Isabella Rodriguez's apartment: main room:bed
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 231, in move
#     return self.execute(maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 170, in execute
#     return execute(self, maze, personas, plan)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/execute.py", line 92, in execute
#     maze.address_tiles["Johnson Park:park:park garden"] #ERRORRRRRRR
#     ~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyError: 'Johnson Park:park:park garden'
# Error.
# Enter option:
