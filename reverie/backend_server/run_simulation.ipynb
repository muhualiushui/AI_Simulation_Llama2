# %%
for i in range(1,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand7\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_rm_$i"
# Out:
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'
# Traceback (most recent call last):
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 615, in <module>
#     rs = ReverieServer(origin, target)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 58, in __init__
#     copyanything(fork_folder, sim_folder)
#   File "/home/jovyan/AI_Simulation_Llama2/reverie/backend_server/global_methods.py", line 221, in copyanything
#     shutil.copytree(src, dst)
#   File "/opt/conda/lib/python3.10/shutil.py", line 559, in copytree
#     return _copytree(entries=entries, src=src, dst=dst, symlinks=symlinks,
#   File "/opt/conda/lib/python3.10/shutil.py", line 457, in _copytree
#     os.makedirs(dst, exist_ok=dirs_exist_ok)
#   File "/opt/conda/lib/python3.10/os.py", line 225, in makedirs
#     mkdir(name, mode)
# FileExistsError: [Errno 17] File exists: '../../environment/frontend_server/storage/rand7'

# %%
for i in range(2,10):
    # !echo -e "base_the_ville_isabella_maria_klaus \n rand2\n run 1\nexit" | python3 reverie.py >> "../../output_shuzhen/10_30/output_10_30_$i"
# Out:
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 579, in _determine_action
#     generate_task_decomp(persona, act_desp, act_dura))
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 164, in generate_task_decomp
#     return run_gpt_prompt_task_decomp(persona, task, duration)[0]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 473, in run_gpt_prompt_task_decomp
#     output = safe_generate_response(prompt, 5, get_fail_safe(),
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/gpt_structure.py", line 257, in safe_generate_response
#     return func_clean_up(curr_gpt_response,prompt=prompt)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/prompt_template/run_gpt_prompt.py", line 407, in __func_clean_up
#     duration = int(k[1].split(",")[0].strip())
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ValueError: invalid literal for int() with base 10: 'x'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: ' main room'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: ' main room'
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 106, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^
# KeyError: 'kitchen'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 959, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 629, in _determine_action
#     act_game_object = generate_action_game_object(act_desp, act_address,
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 221, in generate_action_game_object
#     if not persona.s_mem.get_str_accessible_arena_game_objects(act_address):
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/memory_structures/spatial_memory.py", line 108, in get_str_accessible_arena_game_objects
#     x = ", ".join(list(self.tree[curr_world][curr_sector][curr_arena.lower()]))
#                        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^
# KeyError: 'kitchen'

# %%
! echo -e "base_the_ville_isabella_maria_klaus \n rand1\n run 1\nexit" | python3 reverie.py
# Out:
# Enter the name of the forked simulation: Enter the name of the new simulation: Note: The agents in this simulation package are computational
# constructs powered by generative agents architecture and LLM. We
# clarify that these agents lack human-like agency, consciousness,
# and independent decision-making.
# ---
# Enter option: The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'GPT4Tokenizer'.
# The class this function is called from is 'GPT2TokenizerFast'.
# GNS FUNCTION: <generate_wake_up_hour>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# According to the given information, Isabella Rodriguez typically goes to bed at 11 pm and wakes up at 6 am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez wakes up at 6am every morning.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez typically wakes up at around 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez typically wakes up at around 6am.
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Monday February 13th
# === persona/prompt_template/v2/wake_up_hour_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Isabella']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Isabella's wake up hour:
#
# ~~~ prompt    ----------------------------------------------------
# 8
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_first_daily_plan>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Isabella Rodriguez plans to open Hobbs Cafe at 8am and work at the counter until 8pm, closing the cafe for the night. Since today is Monday February 13th, she will likely be busy preparing for her Valentine's Day party on February 14th, which she has been planning for a while now. She may be gathering party material and making final preparations for the event at the cafe.
# === persona/prompt_template/v2/daily_planning_v6.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ["Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", 'Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.', 'Monday February 13', 'Isabella', '8:00 am']
#
# ~~~ prompt_input    ----------------------------------------------
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# In general, Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Today is Monday February 13. Here is Isabella's plan today in broad-strokes (with the time of the day. e.g., have a lunch at 12:00 pm, watch TV from 7 to 8 pm): 1) wake up and complete the morning routine at 8:00 am, 2)
#
# ~~~ prompt    ----------------------------------------------------
# ['wake up and complete the morning routine at 8:00 am']
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_hourly_schedule>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# preparing for opening Hobbs Cafe for the day.
#
# [Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.
#
# [Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
#
# [Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
#
# [Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
#
# [Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
#
# [Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
#
# [Monday February 13 -- 9:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed.
#
# [Monday February 13 -- 10:00 PM] Activity: Isabella is sleeping to prepare for another busy day at Hobbs Cafe.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", '\n[(ID:SxHCHc) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:RWWLKA) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:TBpEPQ) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:uBzktR) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:vYX7fu) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:1MUEBo) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:sxz0dI) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:z4Ki95) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n\n', "Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am", '', '[(ID:4CxkIU) Monday February 13 -- 08:00 AM] Activity: Isabella is']
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:SxHCHc) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:RWWLKA) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:TBpEPQ) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:uBzktR) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:vYX7fu) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:1MUEBo) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:sxz0dI) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:z4Ki95) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:4CxkIU) Monday February 13 -- 08:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# preparing for opening Hobbs Cafe for the day.
#
# [Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.
#
# [Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
#
# [Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
#
# [Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
#
# [Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
#
# [Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
#
# [Monday February 13 -- 9:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed.
#
# [Monday February 13 -- 10:00 PM] Activity: Isabella is sleeping to prepare for another busy day at Hobbs Cafe
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# opening Hobbs Cafe and greeting customers.
#
# 2) manage customer orders and ensure smooth operation from 9:00 am to 5:00 pm
# [(ID:7cCyJj) Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
# [(ID:3VjP70) Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
# [(ID:5lnSN1) Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
# [(ID:2ZyFJm) Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
# [(ID:RS7tKf) Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
# [(ID:d4NInI) Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
# [(ID:NAqmlK) Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
# 3) take a break and prepare for Valentine's Day party from 5:00 pm to 7:00 pm
# [(ID:upztyQ) Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
# [(ID:gsAR5j) Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
# [(ID:d3K2tB) Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
# 4) close the cafe and prepare for tomorrow from 7:00 pm to 9:00 pm
# [(ID:NAqmlK) Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
# 5) complete any remaining tasks and get ready for bed from 9:00 pm to 10:00 pm
# [(ID:NAqmlK) Monday February 13 -- 10:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:10RECC) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:tov8qq) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:5lnSN1) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:RS7tKf) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:NAqmlK) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:upztyQ) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:d4NInI) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:gsAR5j) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:3VjP70) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing for opening Hobbs Cafe for the day.\n\n[Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.\n\n[Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.\n\n[Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.\n\n[Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.\n\n[Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.\n\n[Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.\n\n[Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.\n\n[Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.\n\n[Monday February 13 -- 5:00 PM] Activity: Isabella is taking a b ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:10RECC) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:tov8qq) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:5lnSN1) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:RS7tKf) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:NAqmlK) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:upztyQ) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:d4NInI) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:gsAR5j) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:3VjP70) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing for opening Hobbs Cafe for the day.
#
# [Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.
#
# [Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
#
# [Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
#
# [Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
#
# [Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
#
# [Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
#
# [Monday February 13 -- 9:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed.
#
# [Monday February 13 -- 10:00 PM] Activity: Isabella is sleeping to prepare for another busy day at Hobbs Cafe
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:srFefH) Monday February 13 -- 09:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# opening Hobbs Cafe and greeting customers.
#
# 2) manage customer orders and ensure smooth operation from 9:00 am to 5:00 pm
# [(ID:7cCyJj) Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
# [(ID:3VjP70) Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
# [(ID:5lnSN1) Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
# [(ID:2ZyFJm) Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
# [(ID:RS7tKf) Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
# [(ID:d4NInI) Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
# [(ID:NAqmlK) Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
# 3) take a break and prepare for Valentine's Day party from 5:00 pm to 7:00 pm
# [(ID:upztyQ) Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
# [(ID:gsAR5j) Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
# [(ID:d3K2tB) Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
# 4) close the cafe and prepare for tomorrow from 7:00 pm to 9:00 pm
# [(ID:NAqmlK) Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
# 5) complete any remaining tasks and get ready for bed from 9:00 pm to 10:00 pm
# [(ID:NAqmlK) Monday February 13 -- 10:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# preparing for the Valentine's Day party at Hobbs Cafe, and
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['[Monday February 13 -- 00:00 AM] Activity: [Fill in]\n[Monday February 13 -- 01:00 AM] Activity: [Fill in]\n[Monday February 13 -- 02:00 AM] Activity: [Fill in]\n[Monday February 13 -- 03:00 AM] Activity: [Fill in]\n[Monday February 13 -- 04:00 AM] Activity: [Fill in]\n[Monday February 13 -- 05:00 AM] Activity: [Fill in]\n[Monday February 13 -- 06:00 AM] Activity: [Fill in]\n[Monday February 13 -- 07:00 AM] Activity: [Fill in]\n[Monday February 13 -- 08:00 AM] Activity: [Fill in]\n[Monday February 13 -- 09:00 AM] Activity: [Fill in]\n[Monday February 13 -- 10:00 AM] Activity: [Fill in]\n[Monday February 13 -- 11:00 AM] Activity: [Fill in]\n[Monday February 13 -- 12:00 PM] Activity: [Fill in]\n[Monday February 13 -- 01:00 PM] Activity: [Fill in]\n[Monday February 13 -- 02:00 PM] Activity: [Fill in]\n[Monday February 13 -- 03:00 PM] Activity: [Fill in]\n[Monday February 13 -- 04:00 PM] Activity: [Fill in]\n[Monday February 13 -- 05:00 PM] Activity: [Fill in]\n[Monday February 13 -- 06:00 PM] Activity: [Fill in]\n[Monday February 13 -- 07:00 PM] Activity: [Fill in]\n[Monday February 13 -- 08:00 PM] Activity: [Fill in]\n[Monday February 13 -- 09:00 PM] Activity: [Fill in]\n[Monday February 13 -- 10:00 PM] Activity: [Fill in]\n[Monday February 13 -- 11:00 PM] Activity: [Fill in]', "Name: Isabella Rodriguez\nAge: 34\nInnate traits: friendly, outgoing, hospitable\nLearned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.\nCurrently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.\nLifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.\nDaily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.\nCurrent Date: Monday February 13\n", "\n[(ID:FMy7kG) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping\n[(ID:4iAQQE) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping\n[(ID:gmrGJ4) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping\n[(ID:NfnDU9) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping\n[(ID:zPCR6o) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping\n[(ID:3Brpgu) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping\n[(ID:gHx6h4) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping\n[(ID:nMB8Zg) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping\n[(ID:lvfoF2) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing for opening Hobbs Cafe for the day.\n\n[Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.\n\n[Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.\n\n[Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.\n\n[Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.\n\n[Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.\n\n[Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.\n\n[Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.\n\n[Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.\n\n[Monday February 13 -- 5:00 PM] Activity: Isabella is taking a b ...
#
# ~~~ prompt_input    ----------------------------------------------
# Hourly schedule format:
# [Monday February 13 -- 00:00 AM] Activity: [Fill in]
# [Monday February 13 -- 01:00 AM] Activity: [Fill in]
# [Monday February 13 -- 02:00 AM] Activity: [Fill in]
# [Monday February 13 -- 03:00 AM] Activity: [Fill in]
# [Monday February 13 -- 04:00 AM] Activity: [Fill in]
# [Monday February 13 -- 05:00 AM] Activity: [Fill in]
# [Monday February 13 -- 06:00 AM] Activity: [Fill in]
# [Monday February 13 -- 07:00 AM] Activity: [Fill in]
# [Monday February 13 -- 08:00 AM] Activity: [Fill in]
# [Monday February 13 -- 09:00 AM] Activity: [Fill in]
# [Monday February 13 -- 10:00 AM] Activity: [Fill in]
# [Monday February 13 -- 11:00 AM] Activity: [Fill in]
# [Monday February 13 -- 12:00 PM] Activity: [Fill in]
# [Monday February 13 -- 01:00 PM] Activity: [Fill in]
# [Monday February 13 -- 02:00 PM] Activity: [Fill in]
# [Monday February 13 -- 03:00 PM] Activity: [Fill in]
# [Monday February 13 -- 04:00 PM] Activity: [Fill in]
# [Monday February 13 -- 05:00 PM] Activity: [Fill in]
# [Monday February 13 -- 06:00 PM] Activity: [Fill in]
# [Monday February 13 -- 07:00 PM] Activity: [Fill in]
# [Monday February 13 -- 08:00 PM] Activity: [Fill in]
# [Monday February 13 -- 09:00 PM] Activity: [Fill in]
# [Monday February 13 -- 10:00 PM] Activity: [Fill in]
# [Monday February 13 -- 11:00 PM] Activity: [Fill in]
# ===
# Name: Isabella Rodriguez
# Age: 34
# Innate traits: friendly, outgoing, hospitable
# Learned traits: Isabella Rodriguez is a cafe owner of Hobbs Cafe who loves to make people feel welcome. She is always looking for ways to make the cafe a place where people can come to relax and enjoy themselves.
# Currently: Isabella Rodriguez is planning on having a Valentine's Day party at Hobbs Cafe with her customers on February 14th, 2023 at 5pm. She is gathering party material, and is telling everyone to join the party at Hobbs Cafe on February 14th, 2023, from 5pm to 7pm.
# Lifestyle: Isabella Rodriguez goes to bed around 11pm, awakes up around 6am.
# Daily plan requirement: Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Current Date: Monday February 13
#
#
# [(ID:FMy7kG) Monday February 13 -- 00:00 AM] Activity: Isabella is sleeping
# [(ID:4iAQQE) Monday February 13 -- 01:00 AM] Activity: Isabella is sleeping
# [(ID:gmrGJ4) Monday February 13 -- 02:00 AM] Activity: Isabella is sleeping
# [(ID:NfnDU9) Monday February 13 -- 03:00 AM] Activity: Isabella is sleeping
# [(ID:zPCR6o) Monday February 13 -- 04:00 AM] Activity: Isabella is sleeping
# [(ID:3Brpgu) Monday February 13 -- 05:00 AM] Activity: Isabella is sleeping
# [(ID:gHx6h4) Monday February 13 -- 06:00 AM] Activity: Isabella is sleeping
# [(ID:nMB8Zg) Monday February 13 -- 07:00 AM] Activity: Isabella is sleeping
# [(ID:lvfoF2) Monday February 13 -- 08:00 AM] Activity: Isabella is preparing for opening Hobbs Cafe for the day.
#
# [Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.
#
# [Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
#
# [Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
#
# [Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
#
# [Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
#
# [Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
#
# [Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
#
# [Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
#
# [Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
#
# [Monday February 13 -- 9:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed.
#
# [Monday February 13 -- 10:00 PM] Activity: Isabella is sleeping to prepare for another busy day at Hobbs Cafe
# [(ID:UWV1oO) Monday February 13 -- 09:00 AM] Activity: Isabella is opening Hobbs Cafe and greeting customers.
#
# 2) manage customer orders and ensure smooth operation from 9:00 am to 5:00 pm
# [(ID:7cCyJj) Monday February 13 -- 10:00 AM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
# [(ID:3VjP70) Monday February 13 -- 11:00 AM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
# [(ID:5lnSN1) Monday February 13 -- 12:00 PM] Activity: Isabella is preparing the lunch menu for customers and ensuring stock levels remain adequate.
# [(ID:2ZyFJm) Monday February 13 -- 1:00 PM] Activity: Isabella is taking a break and having lunch herself, before resuming her duties at Hobbs Cafe.
# [(ID:RS7tKf) Monday February 13 -- 2:00 PM] Activity: Isabella is managing customer orders and ensuring a smooth operation at Hobbs Cafe.
# [(ID:d4NInI) Monday February 13 -- 3:00 PM] Activity: Isabella is interacting with customers and making sure they are enjoying their time at Hobbs Cafe.
# [(ID:NAqmlK) Monday February 13 -- 4:00 PM] Activity: Isabella is preparing the dinner menu for customers and ensuring stock levels remain adequate.
# 3) take a break and prepare for Valentine's Day party from 5:00 pm to 7:00 pm
# [(ID:upztyQ) Monday February 13 -- 5:00 PM] Activity: Isabella is taking a break and preparing for the Valentine's Day party at Hobbs Cafe.
# [(ID:gsAR5j) Monday February 13 -- 6:00 PM] Activity: Isabella is setting up the cafe for the Valentine's Day party and welcoming customers to the event.
# [(ID:d3K2tB) Monday February 13 -- 7:00 PM] Activity: Isabella is managing the party and ensuring guests are enjoying themselves.
# 4) close the cafe and prepare for tomorrow from 7:00 pm to 9:00 pm
# [(ID:NAqmlK) Monday February 13 -- 8:00 PM] Activity: Isabella is closing Hobbs Cafe for the day and preparing for tomorrow's schedule.
# 5) complete any remaining tasks and get ready for bed from 9:00 pm to 10:00 pm
# [(ID:NAqmlK) Monday February 13 -- 10:00 PM] Activity: Isabella is completing any remaining tasks and getting ready for bed
#
#
# Here the originally intended hourly breakdown of Isabella's schedule today: 1) wake up and complete the morning routine at 8:00 am
# [(ID:p6WCFh) Monday February 13 -- 10:00 AM] Activity: Isabella is
#
# ~~~ prompt    ----------------------------------------------------
# preparing for the Valentine's Day party at Hobbs Cafe, and
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Here is the hourly breakdown of Isabella's schedule today based on her input:
#
# Monday, February 13
# --------------------
#
# 9:00-11:00am - Preparing for opening Hobbs Cafe and greeting customers
#
# 11:00-12:00pm - Managing customer orders and ensuring smooth operation
#
# 12:00-1:00pm - Interacting with customers and making sure they are enjoying their time at Hobbs Cafe
#
# 1:00-2:00pm - Preparing the lunch menu for customers and ensuring stock levels remain adequate
#
# 2:00-3:00pm - Managing customer orders and ensuring smooth operation
#
# 3:00-4:00pm - Interacting with customers and making sure they are enjoying their time at Hobbs Cafe
#
# 4:00-5:00pm - Preparing the dinner menu for customers and ensuring stock levels remain adequate
#
# 5:00-7:00pm - Taking a break to prepare for the Valentine's Day party, setting up the cafe, and welcoming customers
#
# 7:00-8:00pm - Closing Hobbs Cafe for the day and preparing for tomorrow's schedule
#
# 8:00-10:00pm - Completing any remaining tasks and getting ready for bed
#
# Please note that Isabella may have other tasks or responsibilities outside of these hours, but this breakdown provides a general overview of her daily plan requirement.
# === persona/prompt_template/v2/generate_hourly_schedule_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ...
# ["I apologize, it seems that the previous response was truncated. Here is the full hourly breakdown of Isabella's schedule based on the information provided:\n\nMonday, February 13th\n--------------------\n9:00-11:00am - Preparing for opening Hobbs Cafe and greeting customers\n11:00-12:00pm - Managing customer orders and ensuring smooth operation\n12:00-1:00pm - Interacting with customers and making sure they are enjoying their time at Hobbs Cafe\n1:00-2:00pm - Preparing the lunch menu for customers and ensuring stock levels remain adequate\n2:00-3:00pm - Managing customer orders and ensuring smooth operation\n3:00-4:00pm - Interacting with customers and making sure they are enjoying their time at Hobbs Cafe\n4:00-5:00pm - Preparing the dinner menu for customers and ensuring stock levels remain adequate\n5:00-7:00pm - Taking a break to prepare for the Valentine's Day party, setting up the cafe, and welcoming customers\n7:00-8:00pm - Closing Hobbs Cafe for the day and preparing for tomorrow\n8:00-10:00pm - Completing any remaining tasks and getting ready for bed\nPlease note that Isabella may have other tasks or responsibilities outside of these hours, but this breakdown provides a general overview of her daily plan requirement. If you have any further questions, please let me know!", 60]
# ["Please note that I apologize for the confusion, but it seems like the input provided was not complete or accurate. Without a full and accurate representation of Isabella's schedule and plans, I am unable to provide a comprehensive hourly breakdown of her schedule today.\n\nPlease provide me with more information or clarification on Isabella's daily plan and schedule so that I can assist you better", 60]
# ["It appears that you are asking for the hourly breakdown of Isabella's schedule on February 13th, specifically at 8:00am. Based on the information provided, I can see that Isabella has scheduled her day to begin at 9:00am and finish at 8:00pm.\nHowever, it is important to note that without additional context or specific details about what tasks she plans to accomplish during each hour of the day, it is difficult to provide a detailed breakdown of her schedule. If you have more information or questions, I would be happy to assist you further", 60]
# 0
# 17
# Isabella Rodriguez
# ------
# GNS FUNCTION: <generate_action_sector>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# It's not clear from the provided information what task or activity you are trying to complete for Isabella Rodriguez. Could you please provide more context?
# DEBUG Harvey Oak Supply Store ------ Isabella Rodriguez's apartment
# === persona/prompt_template/v1/action_location_sector_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', '\nIsabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.', "Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment", 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez']
#
# ~~~ prompt_input    ----------------------------------------------
# Task -- choose an appropriate area  from the area options for a task at hand.
#
# Sam Kim lives in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Sam Kim is currently in {Sam Kim's house} that has Sam Kim's room, bathroom, kitchen.
# Area options: {Sam Kim's house, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For taking a walk, Sam Kim should go to the following area: {Johnson Park}
# ---
# Jane Anderson lives in {Oak Hill College Student Dormatory} that has Jane Anderson's room.
# Jane Anderson is currently in {Oak Hill College} that has a classroom, library
# Area options: {Oak Hill College Student Dormatory, The Rose and Crown Pub, Hobbs Cafe, Oak Hill College, Johnson Park, Harvey Oak Supply Store, The Willows Market and Pharmacy}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# For eating dinner, Jane Anderson should go to the following area: {Hobbs Cafe}
# ---
# Isabella Rodriguez lives in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez is currently in {Isabella Rodriguez's apartment} that has main room.
# Isabella Rodriguez opens Hobbs Cafe at 8am everyday, and works at the counter until 8pm, at which point she closes the cafe.
# Area options: {Hobbs Cafe, Isabella Rodriguez's apartment, The Rose and Crown Pub, Harvey Oak Supply Store, The Willows Market and Pharmacy, Dorm for Oak Hill College, Johnson Park, Ryan Park's apartment}.
# * Stay in the current area if the activity can be done there. Only go out if the activity needs to take place in another place.
# * Must be one of the "Area options," verbatim.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area: {
#
# ~~~ prompt    ----------------------------------------------------
# Isabella Rodriguez's apartment
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Problem find !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
# GNS FUNCTION: <generate_action_arena>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# main room}
# main room
# === persona/prompt_template/v1/action_location_object_vMar11.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room', 'Isabella Rodriguez', 'sleeping', 'sleeping', 'Isabella Rodriguez', "Isabella Rodriguez's apartment", 'main room']
#
# ~~~ prompt_input    ----------------------------------------------
# Jane Anderson is in kitchen in Jane Anderson's house.
# Jane Anderson is going to Jane Anderson's house that has the following areas: {kitchen,  bedroom, bathroom}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For cooking, Jane Anderson should go to the following area in Jane Anderson's house:
# Answer: {kitchen}
# ---
# Tom Watson is in common room in Tom Watson's apartment.
# Tom Watson is going to Hobbs Cafe that has the following areas: {cafe}
# Stay in the current area if the activity can be done there. Never go into other people's rooms unless necessary.
# For getting coffee, Tom Watson should go to the following area in Hobbs Cafe:
# Answer: {cafe}
# ---
#
# Isabella Rodriguez is going to Isabella Rodriguez's apartment that has the following areas: {main room}
# * Stay in the current area if the activity can be done there.
# * NEVER go into other people's rooms unless necessary.
# Isabella Rodriguez is sleeping. For sleeping, Isabella Rodriguez should go to the following area in Isabella Rodriguez's apartment (MUST pick one of {main room}):
# Answer: {
#
# ~~~ prompt    ----------------------------------------------------
# main room
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# Debug: act_address: ???????????????????????????????????????????????????????????????????????????????????????
# the Ville:Isabella Rodriguez's apartment:main room
# sleeping
# GNS FUNCTION: <generate_action_game_object>
# Identified?????????????????????????????????????/
# main room
# main room
# Identified?????????????????????????????????????/
# main room
# main room
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The most relevant object for the current activity of "sleeping" is the bed.
# Identified?????????????????????????????????????/
# main room
# main room
# === persona/prompt_template/v1/action_object_v2.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['sleeping', 'bed, desk, refrigerator, closet, shelf']
#
# ~~~ prompt_input    ----------------------------------------------
# Current activity: sleep in bed
# Objects available: {bed, easel, closet, painting}
# Pick ONE most relevant object from the objects available: bed
# ---
# Current activity: painting
# Objects available: {easel, closet, sink, microwave}
# Pick ONE most relevant object from the objects available: easel
# ---
# Current activity: cooking
# Objects available: {stove, sink, fridge, counter}
# Pick ONE most relevant object from the objects available: stove
# ---
# Current activity: watch TV
# Objects available: {couch, TV, remote, coffee table}
# Pick ONE most relevant object from the objects available: TV
# ---
# Current activity: study
# Objects available: {desk, computer, chair, bookshelf}
# Pick ONE most relevant object from the objects available: desk
# ---
# Current activity: talk on the phone
# Objects available: {phone, charger, bed, nightstand}
# Pick ONE most relevant object from the objects available: phone
# ---
# Current activity: sleeping
# Objects available: {bed, desk, refrigerator, closet, shelf}
# Pick ONE most relevant object from the objects available:
#
# ~~~ prompt    ----------------------------------------------------
# desk
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_action_pronunciatio>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 4
# CHAT GPT PROMPT
# """
# Convert an action description to an emoji (important: use two or less emojis).
#
# Action description: sleeping
# Emoji:
# """
# Output the response to the prompt above in json. The value for the output must ONLY contain the emojis.
# Example output json:
# {"output": "🛁🧖‍♀️"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 🏡😴
# output1___________________________
# 🏡😴
# GNS FUNCTION: <generate_action_event_triple>
# To see GPT response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# is, sleep)
# ---
# === persona/prompt_template/v2/generate_event_triple_v1.txt
# ~~~ persona    ---------------------------------------------------
# Isabella Rodriguez
#
# ~~~ gpt_param ----------------------------------------------------
# ['Isabella Rodriguez', 'sleeping', 'Isabella Rodriguez']
#
# ~~~ prompt_input    ----------------------------------------------
# Task: Turn the input into (subject, predicate, object).
#
# Input: Sam Johnson is eating breakfast.
# Output: (Dolores Murphy, eat, breakfast)
# ---
# Input: Joon Park is brewing coffee.
# Output: (Joon Park, brew, coffee)
# ---
# Input: Jane Cook is sleeping.
# Output: (Jane Cook, is, sleep)
# ---
# Input: Michael Bernstein is writing email on a computer.
# Output: (Michael Bernstein, write, email)
# ---
# Input: Percy Liang is teaching students in a classroom.
# Output: (Percy Liang, teach, students)
# ---
# Input: Merrie Morris is running on a treadmill.
# Output: (Merrie Morris, run, treadmill)
# ---
# Input: Isabella Rodriguez is sleeping.
# Output: (Isabella Rodriguez,
#
# ~~~ prompt    ----------------------------------------------------
# ('Isabella Rodriguez', 'is', 'sleep')
#
# ~~~ output    ----------------------------------------------------
# None
#
# === END ==========================================================
#
#
#
#
# GNS FUNCTION: <generate_act_obj_desc>
# asdhfapsh8p9hfaiafdsi;ldfj as DEBUG 6
# CHAT GPT PROMPT
# """
# Task: We want to understand the state of an object that is being used by someone.
#
# ---
# Example 1:
# Kelly is writing on the desk
# desk is: using by Kelly
#
# Example 2:
# Jason is fixing the TV
# Tv is: fixing by Kelly
#
# Example 3:
# Jessica is spleeping on the bed
# bed is: using by Jessica
# ---
#
# Now, We want to know about desk's state.
# Isabella Rodriguez is sleeping with the desk.
# desk is:
# """
# Output the response to the prompt above in json. The output should ONLY contain the phrase that should go in <fill in>.
# Example output json:
# {"output": "being fixed"}
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ---- repeat count:
#  0
#
# ~~~~
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ---- repeat count:
#  1
#
# ~~~~
# to see curr_gpt_response~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# ---- repeat count:
#  2
#
# ~~~~
# output2___________________________
# False
# Traceback (most recent call last):
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 472, in open_server
#     rs.start_server(int_count)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/reverie.py", line 379, in start_server
#     next_tile, pronunciatio, description = persona.move(
#                                            ^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 222, in move
#     plan = self.plan(maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/persona.py", line 148, in plan
#     return plan(self, maze, personas, new_day, retrieved)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 963, in plan
#     _determine_action(persona, maze)
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 639, in _determine_action
#     act_obj_desp = generate_act_obj_desc(act_game_object, act_desp, persona)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/muhualiushui/Desktop/AI_Simulation_Llama2/reverie/backend_server/persona/cognitive_modules/plan.py", line 269, in generate_act_obj_desc
#     return run_gpt_prompt_act_obj_desc(act_game_object, act_desp, persona)[0]
#            ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^^^
# TypeError: 'NoneType' object is not subscriptable
# Error.
# Enter option:
